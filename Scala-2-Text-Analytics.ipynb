# %%
# %libraryDependencies += "org.apache.spark" %% "spark-assembly" % "1.1.0"

# %%
# %resolvers += "Maven Central" at "https://repo1.maven.org/maven2/"

# %%
# %update
# Out:
# [info] Resolving org.apache.spark#spark-assembly_2.10;1.1.0 ...
# [info] Resolving org.apache.spark#spark-core_2.10;1.1.0 ...
# [info] Resolving org.apache.hadoop#hadoop-client;1.0.4 ...
# [info] Resolving org.apache.hadoop#hadoop-core;1.0.4 ...
# [info] Resolving xmlenc#xmlenc;0.52 ...
# [info] Resolving commons-codec#commons-codec;1.5 ...
# [info] Resolving org.apache.commons#commons-math;2.1 ...
# [info] Resolving commons-configuration#commons-configuration;1.6 ...
# [info] Resolving commons-collections#commons-collections;3.2.1 ...
# [info] Resolving commons-lang#commons-lang;2.4 ...
# [info] Resolving commons-logging#commons-logging;1.1.1 ...
# [info] Resolving commons-digester#commons-digester;1.8 ...
# [info] Resolving commons-beanutils#commons-beanutils;1.7.0 ...
# [info] Resolving commons-beanutils#commons-beanutils-core;1.8.0 ...
# [info] Resolving commons-net#commons-net;2.2 ...
# [info] Resolving commons-el#commons-el;1.0 ...
# [info] Resolving hsqldb#hsqldb;1.8.0.10 ...
# [info] Resolving oro#oro;2.0.8 ...
# [info] Resolving org.codehaus.jackson#jackson-mapper-asl;1.8.8 ...
# [info] Resolving org.codehaus.jackson#jackson-core-asl;1.8.8 ...
# [info] Resolving net.java.dev.jets3t#jets3t;0.7.1 ...
# [info] Resolving commons-httpclient#commons-httpclient;3.1 ...
# [info] Resolving org.apache.curator#curator-recipes;2.4.0 ...
# [info] Resolving org.apache.curator#curator-framework;2.4.0 ...
# [info] Resolving org.apache.curator#curator-client;2.4.0 ...
# [info] Resolving org.slf4j#slf4j-api;1.7.5 ...
# [info] Resolving org.apache.zookeeper#zookeeper;3.4.5 ...
# [info] Resolving org.slf4j#slf4j-log4j12;1.7.5 ...
# [info] Resolving log4j#log4j;1.2.17 ...
# [info] Resolving jline#jline;0.9.94 ...
# [info] Resolving com.google.guava#guava;14.0.1 ...
# [info] Resolving org.eclipse.jetty#jetty-plus;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty.orbit#javax.transaction;1.1.1.v201105210645 ...
# [info] Resolving org.eclipse.jetty#jetty-webapp;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-xml;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-util;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-servlet;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-security;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-server;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty.orbit#javax.servlet;3.0.0.v201112011016 ...
# [info] Resolving org.eclipse.jetty#jetty-continuation;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-http;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-io;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty#jetty-jndi;8.1.14.v20131031 ...
# [info] Resolving org.eclipse.jetty.orbit#javax.mail.glassfish;1.4.1.v201005082020 ...
# [info] Resolving org.eclipse.jetty.orbit#javax.activation;1.1.0.v201105071233 ...
# [info] Resolving org.apache.commons#commons-lang3;3.3.2 ...
# [info] Resolving com.google.code.findbugs#jsr305;1.3.9 ...
# [info] Resolving org.slf4j#jul-to-slf4j;1.7.5 ...
# [info] Resolving org.slf4j#jcl-over-slf4j;1.7.5 ...
# [info] Resolving com.ning#compress-lzf;1.0.0 ...
# [info] Resolving org.xerial.snappy#snappy-java;1.0.5.3 ...
# [info] Resolving net.jpountz.lz4#lz4;1.2.0 ...
# [info] Resolving com.twitter#chill_2.10;0.3.6 ...
# [info] Resolving org.scala-lang#scala-library;2.10.4 ...
# [info] Resolving com.twitter#chill-java;0.3.6 ...
# [info] Resolving com.esotericsoftware.kryo#kryo;2.21 ...
# [info] Resolving com.esotericsoftware.reflectasm#reflectasm;1.07 ...
# [info] Resolving com.esotericsoftware.minlog#minlog;1.2 ...
# [info] Resolving org.objenesis#objenesis;1.2 ...
# [info] Resolving org.spark-project.akka#akka-remote_2.10;2.2.3-shaded-protobuf ...
# [info] Resolving org.spark-project.akka#akka-actor_2.10;2.2.3-shaded-protobuf ...
# [info] Resolving com.typesafe#config;1.0.2 ...
# [info] Resolving io.netty#netty;3.6.6.Final ...
# [info] Resolving org.spark-project.protobuf#protobuf-java;2.4.1-shaded ...
# [info] Resolving org.uncommons.maths#uncommons-maths;1.2.2a ...
# [info] Resolving org.spark-project.akka#akka-slf4j_2.10;2.2.3-shaded-protobuf ...
# [info] Resolving org.json4s#json4s-jackson_2.10;3.2.10 ...
# [info] Resolving org.json4s#json4s-core_2.10;3.2.10 ...
# [info] Resolving org.json4s#json4s-ast_2.10;3.2.10 ...
# [info] Resolving com.thoughtworks.paranamer#paranamer;2.6 ...
# [info] Resolving org.scala-lang#scalap;2.10.4 ...
# [info] Resolving org.scala-lang#scala-compiler;2.10.4 ...
# [info] Resolving org.scala-lang#scala-reflect;2.10.4 ...
# [info] Resolving com.fasterxml.jackson.core#jackson-databind;2.3.1 ...
# [info] Resolving com.fasterxml.jackson.core#jackson-annotations;2.3.0 ...
# [info] Resolving com.fasterxml.jackson.core#jackson-core;2.3.1 ...
# [info] Resolving colt#colt;1.2.0 ...
# [info] Resolving concurrent#concurrent;1.3.4 ...
# [info] Resolving org.apache.mesos#mesos;0.18.1 ...
# [info] Resolving io.netty#netty-all;4.0.23.Final ...
# [info] Resolving com.clearspring.analytics#stream;2.7.0 ...
# [info] Resolving com.codahale.metrics#metrics-core;3.0.0 ...
# [info] Resolving com.codahale.metrics#metrics-jvm;3.0.0 ...
# [info] Resolving com.codahale.metrics#metrics-json;3.0.0 ...
# [info] Resolving com.codahale.metrics#metrics-graphite;3.0.0 ...
# [info] Resolving org.tachyonproject#tachyon-client;0.5.0 ...
# [info] Resolving org.tachyonproject#tachyon;0.5.0 ...
# [info] Resolving commons-io#commons-io;2.4 ...
# [info] Resolving org.spark-project#pyrolite;2.0.1 ...
# [info] Resolving net.sf.py4j#py4j;0.8.2.1 ...
# [info] Resolving org.apache.spark#spark-bagel_2.10;1.1.0 ...
# [info] Resolving org.apache.spark#spark-mllib_2.10;1.1.0 ...
# [info] Resolving org.apache.spark#spark-streaming_2.10;1.1.0 ...
# [info] Resolving org.jblas#jblas;1.2.3 ...
# [info] Resolving org.scalanlp#breeze_2.10;0.9 ...
# [info] Resolving org.scalanlp#breeze-macros_2.10;0.3.1 ...
# [info] Resolving org.scalamacros#quasiquotes_2.10;2.0.0-M8 ...
# [info] Resolving com.github.fommil.netlib#core;1.1.2 ...
# [info] Resolving net.sourceforge.f2j#arpack_combined_all;0.1 ...
# [info] Resolving net.sf.opencsv#opencsv;2.3 ...
# [info] Resolving com.github.rwl#jtransforms;2.4.0 ...
# [info] Resolving org.spire-math#spire_2.10;0.7.4 ...
# [info] Resolving org.spire-math#spire-macros_2.10;0.7.4 ...
# [info] Resolving org.scalamacros#quasiquotes_2.10;2.0.0 ...
# [info] Resolving org.apache.spark#spark-repl_2.10;1.1.0 ...
# [info] Resolving org.scala-lang#jline;2.10.4 ...
# [info] Resolving org.fusesource.jansi#jansi;1.4 ...
# [info] Resolving org.apache.spark#spark-graphx_2.10;1.1.0 ...
# [info] Resolving org.apache.spark#spark-sql_2.10;1.1.0 ...
# [info] Resolving org.apache.spark#spark-catalyst_2.10;1.1.0 ...
# [info] Resolving org.scalamacros#quasiquotes_2.10;2.0.1 ...
# [info] Resolving com.twitter#parquet-column;1.4.3 ...
# [info] Resolving com.twitter#parquet-common;1.4.3 ...
# [info] Resolving com.twitter#parquet-encoding;1.4.3 ...
# [info] Resolving com.twitter#parquet-generator;1.4.3 ...
# [info] Resolving com.twitter#parquet-hadoop;1.4.3 ...
# [info] Resolving com.twitter#parquet-format;2.0.0 ...
# [info] Resolving com.twitter#parquet-jackson;1.4.3 ...
# [info] Resolving org.codehaus.jackson#jackson-core-asl;1.9.11 ...

# %%
import org.apache.spark.SparkContext
import org.apache.spark.SparkContext._
val sc = new SparkContext("local[*]", "Intro")
# Out:
# org.apache.spark.SparkContext@3d85d64

# %%
def clean(s: String): String = if (s.endsWith(".") || 
                                   s.endsWith(",")) s.substring(0, s.size - 1) else s

# %%
var lines = sc.textFile("sotu/2009-2014-BO.txt")
val wordCountBO = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountBO.count()
# Out:
# 4835

# %%
lines = sc.textFile("sotu/2001-2008-GWB.txt")
val wordCountGWB = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountGWB.count()
# Out:
# 4958

# %%
lines = sc.textFile("sotu/1994-2000-WJC.txt")
val wordCountWJC = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountWJC.count()
# Out:
# 5476

# %%
lines = sc.textFile("sotu/1961-1963-JFK.txt")
val wordCountJFK = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountJFK.count()
# Out:
# 3656

# %%
lines = sc.textFile("sotu/1934-1945-FDR.txt")
val wordCountFDR = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountFDR.count()
# Out:
# 5933

# %%
lines = sc.textFile("sotu/1861-1864-AL.txt")
val wordCountAL = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountAL.count()
# Out:
# 4157

# %%
lines = sc.textFile("sotu/1790-1796-GW.txt")
val wordCountGW = lines
  .flatMap(_.split(" ")
    .map(_.toLowerCase.trim)
    .map(clean)
    .map(word => (word, 1)))
  .reduceByKey(_ + _)
wordCountGW.count()
# Out:
# 2951

# %%
val commonWords = Array("us","has","all", "they", "from", "who","what","on","by","more","as","not","their","can",
                             "new","it","but","be","are","--","i","have","this","will","for","with","is","that","in",
                             "our","we","a","of","to","and","the","that's","or","make","do","you","at","it\'s","than",
                             "if","know","last","about","no","just","now","an","because","<p>we","why","we\'ll","how",
                             "two","also","every","come","we've","year","over","get","take","one","them","we\'re","need",
                             "want","when","like","most","-","been","first","where","so","these","they\'re","good","would",
                             "there","should","-->","<!--","up","i\'m","his","their","which","may","were","such","some",
                             "those","was","here","she","he","its","her","his","don\'t","i\'ve","what\'s","didn\'t",
                             "shouldn\'t","(applause.)","let\'s","doesn\'t")
# Out:
# [Ljava.lang.String;@1e749527

# %%
val wordCountBO1 = wordCountBO.sortBy(_._2, ascending = false)
# Out:
# MappedRDD[32] at sortBy at <console>:15

# %%
wordCountBO1.take(10).foreach(println)
# Out:
# (the,1812)
# (and,1375)
# (to,1351)
# (of,1013)
# (a,802)
# (that,778)
# (we,719)
# (our,698)
# (in,637)
# (,568)

# %%
val wordCountBOClean = wordCountBO1.filter(t => !commonWords.contains(t._1))
# Out:
# FilteredRDD[33] at filter at <console>:17

# %%
wordCountBOClean.count()
# Out:
# 4729

# %%
wordCountBOClean.collect().foreach(println)
# Out:
# (,568)
# (jobs,148)
# (people,144)
# (american,133)
# (america,131)
# (years,116)
# (work,108)
# (americans,105)
# (time,89)
# (energy,87)
# (tonight,84)
# (congress,83)
# (country,82)
# (help,81)
# (economy,79)
# (tax,76)
# (right,75)
# (businesses,69)
# (my,65)
# (world,63)
# (education,58)
# (government,58)
# (care,57)
# (home,57)
# (families,56)
# (next,56)
# (must,56)
# (health,55)
# (nation,55)
# (business,54)
# (future,54)
# (even,53)
# (back,53)
# (job,51)
# (reform,51)
# (out,50)
# (states,50)
# (deficit,48)
# (down,47)
# (give,47)
# (put,46)
# (me,44)
# (many,44)
# (support,44)
# (security,43)
# (into,42)
# (together,41)
# (your,41)
# (other,40)
# (too,40)
# (after,40)
# (today,40)
# (college,40)
# (only,39)
# (own,39)
# (way,39)
# (can't,39)
# (keep,39)
# (day,38)
# (still,38)
# (working,38)
# (plan,38)
# (through,38)
# (united,37)
# (million,36)
# (already,36)
# (made,36)
# (schools,36)
# (go,35)
# (same,35)
# (change,35)
# (small,35)
# (workers,35)
# (clean,35)
# (create,34)
# (again,33)
# (children,33)
# (financial,33)
# (never,32)
# (hard,32)
# (companies,32)
# (end,31)
# (without,30)
# (responsibility,30)
# (budget,30)
# (believe,29)
# (any,29)
# (women,29)
# (system,29)
# (power,29)
# (law,28)
# (america's,28)
# (money,28)
# (best,28)
# (lead,28)
# (chance,28)
# (war,28)
# (pay,28)
# (better,28)
# (cuts,28)
# (while,28)
# (place,28)
# (before,28)
# (could,28)
# (bill,28)
# (away,27)
# (act,27)
# (students,27)
# (had,27)
# (across,27)
# (each,27)
# (nearly,27)
# (another,27)
# (oil,26)
# (cut,26)
# (part,26)
# (millions,26)
# (invest,26)
# (finally,26)
# (sure,26)
# (republicans,25)
# (high,25)
# (president,25)
# (afford,25)
# (young,25)
# (let,25)
# (ago,25)
# (making,25)
# (said,25)
# (kids,25)
# (both,25)
# (cannot,25)
# (leaders,24)
# (spending,24)
# (values,24)
# (single,24)
# (ever,24)
# (administration,24)
# (lives,24)
# (innovation,24)
# (communities,24)
# (off,24)
# (credit,24)
# (continue,24)
# (state,24)
# (recovery,24)
# (am,23)
# (school,23)
# (democrats,23)
# (men,23)
# (long,23)
# (market,23)
# (community,23)
# (debt,23)
# (citizens,23)
# (protect,23)
# (gas,23)
# (troops,23)
# (ask,23)
# (took,23)
# (meet,23)
# (crisis,23)
# (bring,22)
# (well,22)
# (built,22)
# (costs,22)
# (insurance,22)
# (stand,22)
# (federal,22)
# (opportunity,22)
# (percent,22)
# (save,22)
# (research,22)
# (see,22)
# (cost,22)
# (great,22)
# (banks,22)
# (office,21)
# (countries,21)
# (nuclear,21)
# (reduce,21)
# (say,21)
# (higher,21)
# (economic,21)
# (against,21)
# (industry,20)
# (done,20)
# (means,20)
# (investments,20)
# (technology,20)
# (recession,20)
# (did,20)
# (success,20)
# (taxes,20)
# (company,20)
# (union,20)
# (progress,20)
# (promise,20)
# (always,20)
# (washington,19)
# (manufacturing,19)
# (few,19)
# (set,19)
# (vote,19)
# (child,19)
# (three,19)
# (chamber,19)
# (start,19)
# (decade,19)
# (different,19)
# (move,19)
# (pass,19)
# (does,19)
# (half,19)
# (afghanistan,18)
# (since,18)
# (raise,18)
# (send,18)
# (life,18)
# (four,18)
# (enough,18)
# (public,18)
# (look,18)
# (goal,18)
# (possible,18)
# (military,18)
# (race,18)
# (being,18)
# (history,17)
# (stronger,17)
# (family,17)
# (nations,17)
# (building,17)
# (generation,17)
# (century,17)
# (trillion,17)
# (serve,17)
# (programs,17)
# (rules,17)
# (strong,17)
# (face,17)
# (use,17)
# (decades,17)
# (behind,16)
# (stop,16)
# (big,16)
# (largest,16)
# (training,16)
# (address,16)
# (build,16)
# (deserve,16)
# (house,16)
# (national,16)
# (created,16)
# (parties,16)
# (action,16)
# (fact,16)
# (passed,16)
# (colleges,16)
# (global,16)
# (matter,16)
# (forward,16)
# (commitment,16)
# (housing,16)
# (ahead,16)
# (dollars,16)
# (iraq,16)
# (aren't,16)
# (around,16)
# (forces,15)
# (trade,15)
# (sent,15)
# (there's,15)
# (agree,15)
# (skills,15)
# (program,15)
# (live,15)
# (science,15)
# (challenges,15)
# (sense,15)
# (example,15)
# (strengthen,15)
# (five,15)
# (worked,15)
# (teachers,15)
# (afghan,15)
# (days,15)
# (investment,15)
# (course,15)
# (idea,15)
# (helping,15)
# (grow,15)
# (won't,15)
# (necessary,15)
# (begin,15)
# (leadership,15)
# (once,15)
# (al,15)
# (issue,15)
# (bipartisan,15)
# (growth,15)
# (free,14)
# (helped,14)
# (medicare,14)
# (willing,14)
# (rest,14)
# (defense,14)
# (getting,14)
# (effort,14)
# (reforms,14)
# (full,14)
# (bad,14)
# (china,14)
# (find,14)
# (months,14)
# (everyone,14)
# (efforts,14)
# (thousands,14)
# (dream,14)
# (rights,14)
# (student,14)
# (then,14)
# (makes,14)
# (parents,14)
# (needs,14)
# (steps,14)
# (street,14)
# (prosperity,14)
# (rates,14)
# (veterans,13)
# (win,13)
# (open,13)
# (access,13)
# (homes,13)
# (able,13)
# (think,13)
# (real,13)
# (middle-class,13)
# (prevent,13)
# (week,13)
# (difficult,13)
# (going,13)
# (hire,13)
# (products,13)
# (benefits,13)
# (instead,13)
# (spend,13)
# (world's,13)
# (ideas,13)
# (between,13)
# (things,13)
# (left,13)
# (much,13)
# (everything,13)
# (common,13)
# (loans,13)
# (private,13)
# (savings,13)
# (growing,13)
# (middle,13)
# (top,13)
# (bless,13)
# (problem,13)
# (tomorrow,13)
# (abroad,13)
# (you're,13)
# (hold,13)
# (further,12)
# (equal,12)
# (allies,12)
# (fight,12)
# (earth,12)
# (projects,12)
# (iran,12)
# (under,12)
# (qaeda,12)
# (easy,12)
# (yet,12)
# (party,12)
# (class,12)
# (happen,12)
# (wage,12)
# (fair,12)
# (speak,12)
# (god,12)
# (dreams,12)
# (secure,12)
# (old,12)
# (less,12)
# (cars,12)
# (seen,12)
# (within,12)
# (doing,12)
# (longer,12)
# (soon,12)
# (republican,12)
# (told,12)
# (natural,12)
# (long-term,12)
# (require,12)
# (whether,12)
# (members,12)
# (share,12)
# (wait,12)
# (politics,12)
# (solar,12)
# (foreign,11)
# (lay,11)
# (buy,11)
# (little,11)
# (ensure,11)
# (faith,11)
# (confidence,11)
# (comprehensive,11)
# (information,11)
# (step,11)
# (man,11)
# (industries,11)
# (wall,11)
# (places,11)
# (asked,11)
# (succeed,11)
# (bills,11)
# (threat,11)
# (got,11)
# (expand,11)
# (affordable,11)
# (incentives,11)
# (times,11)
# (responsible,11)
# (approach,11)
# (tough,11)
# (strength,11)
# (folks,11)
# (markets,11)
# (code,11)
# (fellow,11)
# (democracy,11)
# (lending,11)
# (others,11)
# (retirement,11)
# (reach,11)
# (remains,11)
# (walk,11)
# (laws,11)
# (comes,11)
# (stay,11)
# (climate,11)
# (used,11)
# (forge,11)
# (lower,11)
# (eliminate,10)
# (point,10)
# (immigration,10)
# (level,10)
# (worse,10)
# (reason,10)
# (increase,10)
# (call,10)
# (paying,10)
# (helps,10)
# (korea,10)
# (problems,10)
# (lost,10)
# (basic,10)
# (minimum,10)
# (senate,10)
# (serious,10)
# (coverage,10)
# (restore,10)
# (woman,10)
# (takes,10)
# (unemployment,10)
# (spirit,10)
# (fix,10)
# (wages,10)
# (weapons,10)
# (safe,10)
# (nothing,10)
# (task,10)
# (vice,10)
# (violence,10)
# (coming,10)
# (far,10)
# (terrorists,10)
# (poverty,10)
# (asking,10)
# (speaker,10)
# (south,10)
# (rebuilding,10)
# (legislation,10)
# (least,10)
# (receive,10)
# (yes,10)
# (infrastructure,10)
# (known,10)
# (turn,10)
# (solve,10)
# (north,10)
# (remember,10)
# (tell,10)
# (greater,9)
# (partnership,9)
# (breaks,9)
# (bigger,9)
# (return,9)
# (later,9)
# (moment,9)
# (thing,9)
# (couldn't,9)
# (focus,9)
# (teacher,9)
# (line,9)
# (simple,9)
# (bringing,9)
# (burden,9)
# (none,9)
# (overseas,9)
# (important,9)
# (offer,9)
# (biden,9)
# (entrepreneurs,9)
# (tuition,9)
# (allowed,9)
# (past,9)
# (talk,9)
# (mission,9)
# (standards,9)
# (understand,9)
# (control,9)
# (regulations,9)
# (choose,9)
# (mr,9)
# (compete,9)
# (threats,9)
# (billion,9)
# (force,9)
# (proposing,9)
# (challenge,9)
# (high-tech,9)
# (expect,9)
# (ones,9)
# (begun,9)
# (including,9)
# (broken,9)
# (might,9)
# (called,9)
# (beyond,9)
# (trying,9)
# (number,9)
# (achieve,9)
# (deserves,9)
# (generations,9)
# (pursue,8)
# (intend,8)
# (remain,8)
# (universities,8)
# (wind,8)
# (high-speed,8)
# (him,8)
# (sanctions,8)
# (agenda,8)
# (wealthiest,8)
# (january,8)
# (struggling,8)
# (peace,8)
# (depend,8)
# (simply,8)
# (factory,8)
# (differences,8)
# (pollution,8)
# (factories,8)
# (executive,8)
# (math,8)
# (who've,8)
# (policy,8)
# (proposed,8)
# (workforce,8)
# ("we,8)
# (starting,8)
# (obama,8)
# (freedom,8)
# (anyone,8)
# (trust,8)
# (join,8)
# (diploma,8)
# (kind,8)
# (hundred,8)
# (ten,8)
# (creating,8)
# (hit,8)
# (age,8)
# (social,8)
# (seniors,8)
# (exports,8)
# (human,8)
# (allow,8)
# (twenty,8)
# (become,8)
# (employees,8)
# (thanks,8)
# (biggest,8)
# (alone,8)
# (needed,8)
# (resources,8)
# (sign,8)
# (decisions,8)
# (debate,8)
# (isn't,8)
# (construction,8)
# (else,8)
# (today's,8)
# (words,8)
# (taken,8)
# (follow,8)
# (reward,8)
# (living,8)
# (greatest,8)
# (depends,8)
# (provide,8)
# (order,7)
# (taxpayer,7)
# (career,7)
# (giving,7)
# (dignity,7)
# (capacity,7)
# (unit,7)
# (came,7)
# (standing,7)
# (taking,7)
# (hands,7)
# (dollar,7)
# (goods,7)
# (hear,7)
# (combat,7)
# (advanced,7)
# (thank,7)
# (proud,7)
# (close,7)
# (diplomacy,7)
# (anything,7)
# (improve,7)
# (parts,7)
# (train,7)
# (town,7)
# (ability,7)
# (spent,7)
# (owners,7)
# (europe,7)
# (says,7)
# (month,7)
# (true,7)
# (six,7)
# (21st,7)
# (rural,7)
# (increased,7)
# (highest,7)
# (***,7)
# (promote,7)
# (uniform,7)
# (barack,7)
# (worker,7)
# (begins,7)
# (i'll,7)
# (feel,7)
# (stock,7)
# (streets,7)
# (very,7)
# (love,7)
# (ways,7)
# (hope,7)
# (massive,7)
# (profits,7)
# (people's,7)
# (lobbyists,7)
# (taxpayers,7)
# (john,7)
# (brought,7)
# (saw,7)
# (develop,7)
# (add,7)
# (funding,7)
# (story,7)
# (person,7)
# (led,7)
# (worst,7)
# (prepared,7)
# (includes,7)
# (gave,7)
# (renewable,7)
# (roads,7)
# (process,7)
# ($1,7)
# (sacrifice,7)
# (shared,7)
# (accountable,7)
# (election,7)
# (fewer,7)
# (clear,7)
# (commission,7)
# (difference,7)
# (earned,7)
# (lose,7)
# (partners,7)
# ("i,7)
# (cory,7)
# (faster,7)
# (service,7)
# (income,7)
# (hand,7)
# (white,7)
# (competition,7)
# (deficits,7)
# (opportunities,7)
# (knew,7)
# (borders,7)
# (someone,6)
# (found,6)
# (often,6)
# (went,6)
# (billions,6)
# (second,6)
# (something,6)
# (recognize,6)
# (hour,6)
# (high-quality,6)
# (asia,6)
# (powerful,6)
# (prescription,6)
# (technologies,6)
# (gun,6)
# (they've,6)
# (worth,6)
# (sell,6)
# (campaign,6)
# (courage,6)
# (manufacturers,6)
# (almost,6)
# (waste,6)
# (plants,6)
# (learning,6)
# (lasting,6)
# (doubling,6)
# (thirty,6)
# (mortgage,6)
# (ideals,6)
# (degree,6)
# (destiny,6)
# (iran's,6)
# (hardworking,6)
# (fully,6)
# (policies,6)
# (demands,6)
# (unless,6)
# (sector,6)
# (labor,6)
# (employers,6)
# (priorities,6)
# (rising,6)
# (economists,6)
# (announcing,6)
# (rate,6)
# (works,6)
# (agreed,6)
# (fear,6)
# (citizenship,6)
# (leading,6)
# (impact,6)
# (air,6)
# (cleaner,6)
# (era,6)
# (rid,6)
# (loopholes,6)
# (eight,6)
# (price,6)
# (third,6)
# (carolina,6)
# (watching,6)
# (institutions,6)
# (interests,6)
# (water,6)
# (urge,6)
# (source,6)
# (haven't,6)
# (strategy,6)
# (major,6)
# (political,6)
# (denied,6)
# (medical,6)
# (thought,6)
# (result,6)
# (double,6)
# (corporations,6)
# (wrong,6)
# (speed,6)
# (neighbors,6)
# (waiting,6)
# (stories,6)
# (dime,6)
# (leave,6)
# (democratic,6)
# (obligations,6)
# (complete,6)
# (show,6)
# (launch,6)
# (ceo,6)
# (reducing,6)
# (local,6)
# (cause,6)
# (risk,6)
# (study,6)
# (production,6)
# (internet,6)
# (break,6)
# (fill,6)
# (red,6)
# (friends,6)
# (auto,6)
# (hopeful,6)
# (named,6)
# (began,6)
# (fall,6)
# (quality,6)
# (encourage,6)
# (hundreds,6)
# (consumers,6)
# (partnerships,6)
# (michelle,6)
# (efficient,6)
# (agreements,6)
# (corporate,6)
# (wants,6)
# (lot,6)
# (actions,6)
# (recently,5)
# (incomes,5)
# (agreement,5)
# (defend,5)
# (negotiations,5)
# (railroad,5)
# (renewed,5)
# (materials,5)
# (shores,5)
# (loan,5)
# (brandon,5)
# (themselves,5)
# (until,5)
# (fighting,5)
# (tired,5)
# (status,5)
# (profitable,5)
# (meanwhile,5)
# (cancer,5)
# (play,5)
# (interest,5)
# (thousand,5)
# (ourselves,5)
# (insist,5)
# (cutting,5)
# (international,5)
# (quarter,5)
# (space,5)
# (civilians,5)
# (enduring,5)
# (food,5)
# (wake,5)
# (launched,5)
# (playing,5)
# (equipment,5)
# (allian
# ces,5)
# (cheaper,5)
# (certain,5)
# (sources,5)
# (sick,5)
# (stake,5)
# (depression,5)
# (earlier,5)
# (meaningful,5)
# (fiscal,5)
# (tape,5)
# (premiums,5)
# (who's,5)
# (trucks,5)
# (read,5)
# (respect,5)
# (ends,5)
# (root,5)
# (expanding,5)
# (deal,5)
# (fraud,5)
# (harder,5)
# (kennedy,5)
# (ship,5)
# (letter,5)
# (earn,5)
# (whatever,5)
# (moving,5)
# (weakened,5)
# (whose,5)
# (purpose,5)
# (2011,5)
# (gives,5)
# (kept,5)
# (medicaid,5)
# (changed,5)
# (debates,5)
# (paid,5)
# (seek,5)
# (bank,5)
# (keeps,5)
# (enforce,5)
# (affiliates,5)
# (decline,5)
# (looking,5)
# (mother,5)
# (development,5)
# (graduate,5)
# (running,5)
# (throughout,5)
# (rescue,5)
# (manufacturer,5)
# (foundation,5)
# (owner,5)
# (pays,5)
# (25,5)
# (entire,5)
# (he's,5)
# (side,5)
# (ground,5)
# (teaching,5)
# (educate,5)
# (fund,5)
# (beginning,5)
# (threaten,5)
# (govern,5)
# (determined,5)
# (weeks,5)
# (record,5)
# (adding,5)
# (desk,5)
# (individual,5)
# (towns,5)
# (amid,5)
# (wrote,5)
# (choice,5)
# (along,5)
# (either,5)
# (proposals,5)
# (battles,5)
# (prepare,5)
# (served,5)
# (influence,5)
# (rebuild,5)
# (intelligence,5)
# (based,5)
# (changing,5)
# (engineering,5)
# (felt,5)
# (seven,5)
# (gets,5)
# (mom,5)
# (safer,5)
# (fought,5)
# (fixing,5)
# (changes,5)
# (critical,5)
# (required,5)
# (special,5)
# (mortgages,5)
# (track,5)
# (officers,5)
# (opened,5)
# (try,5)
# (russia,5)
# (2014,5)
# (paychecks,5)
# (run,5)
# (investing,5)
# (reduction,5)
# (deliver,5)
# (ordered,5)
# (cover,5)
# (passing,5)
# (neither,5)
# (started,5)
# (finish,5)
# (freeze,5)
# (knowing,5)
# (carbon,5)
# (quit,5)
# (healthy,5)
# (putting,5)
# (knows,4)
# (responsibilities,4)
# (son,4)
# (field,4)
# (initiative,4)
# (apart,4)
# (department,4)
# (illegal,4)
# (slowly,4)
# (fuel,4)
# (partner,4)
# (tens,4)
# (question,4)
# (recover,4)
# (girl,4)
# (role,4)
# (bridges,4)
# (surely,4)
# (credits,4)
# (wherever,4)
# (leaving,4)
# (border,4)
# (eager,4)
# (heard,4)
# (upon,4)
# (patients,4)
# (drive,4)
# (assistance,4)
# (potential,4)
# (fastest,4)
# (aside,4)
# (rewarded,4)
# (spur,4)
# (you'd,4)
# (independent,4)
# (towards,4)
# (smarter,4)
# (shift,4)
# (learn,4)
# (failure,4)
# (paycheck,4)
# (choices,4)
# (goes,4)
# (veto,4)
# (domestic,4)
# (extend,4)
# (re-start,4)
# (here's,4)
# (engine,4)
# (hubs,4)
# (car,4)
# (serving,4)
# (laid,4)
# (graduates,4)
# (ordinary,4)
# (priority,4)
# (doctors,4)
# (export,4)
# (fallen,4)
# (distinguished,4)
# (tv,4)
# (tells,4)
# (signed,4)
# (general,4)
# (member,4)
# (seize,4)
# (game,4)
# (concern,4)
# (decision,4)
# (specific,4)
# (planet,4)
# (practices,4)
# (directly,4)
# (connecting,4)
# (measure,4)
# (weapon,4)
# (elected,4)
# (word,4)
# (enforcement,4)
# (added,4)
# (setting,4)
# (police,4)
# (issues,4)
# (committed,4)
# (charge,4)
# (safety,4)
# (rewards,4)
# (confident,4)
# (fifty,4)
# (sake,4)
# (governor,4)
# (rule,4)
# (kid,4)
# (rein,4)
# (farmers,4)
# (tucson,4)
# (shoulder,4)
# (providing,4)
# (supporting,4)
# (urgent,4)
# (shape,4)
# (pull,4)
# (10,4)
# (project,4)
# (main,4)
# (networks,4)
# (cops,4)
# (learned,4)
# (attract,4)
# (east,4)
# (lines,4)
# (detroit,4)
# (city,4)
# (developing,4)
# (launching,4)
# (creation,4)
# (civil,4)
# (effect,4)
# (globe,4)
# (pressure,4)
# (summer,4)
# (arrived,4)
# (talks,4)
# (maintain,4)
# (12,4)
# (confront,4)
# (message,4)
# (announce,4)
# (complicated,4)
# (website,4)
# (plant,4)
# (ready,4)
# (governors,4)
# (core,4)
# (doors,4)
# (americas,4)
# (meant,4)
# (demand,4)
# (achievement,4)
# (value,4)
# (blame,4)
# (york,4)
# (payments,4)
# (direct,4)
# (wars,4)
# (average,4)
# (gone,4)
# (danger,4)
# (honest,4)
# (enterprise,4)
# (quo,4)
# (expectations,4)
# (preschool,4)
# (painful,4)
# (americans:,4)
# (stopped,4)
# (regime,4)
# (daughters,4)
# (lift,4)
# (nor,4)
# (majority,4)
# (team,4)
# (continued,4)
# (teach,4)
# (struggle,4)
# (fields,4)
# (transition,4)
# (relief,4)
# (rescued,4)
# (aspirations,4)
# (authority,4)
# (stable,4)
# (pockets,4)
# (convinced,4)
# (ending,4)
# (experts,4)
# (though,4)
# (gay,4)
# (incredible,4)
# (determination,4)
# (goal:,4)
# (sets,4)
# (leads,4)
# (huge,4)
# (jill,4)
# (classroom,4)
# (full-time,4)
# ("the,4)
# (rewarding,4)
# (smart,4)
# (held,4)
# (sustain,4)
# (during,4)
# (homeowners,4)
# (earns,4)
# (aggressively,4)
# (justice,4)
# (strengthened,4)
# (cooperation,4)
# (interested,4)
# (attacks,4)
# (mean,4)
# (defeat,4)
# (creates,4)
# (grown,4)
# (especially,4)
# (deeply,4)
# (division,4)
# (brothers,4)
# (clear:,4)
# (barely,4)
# (available,4)
# ($250,000,4)
# (path,4)
# (peninsula,4)
# (became,4)
# (shot,3)
# (preventing,3)
# (payment,3)
# (ignore,3)
# (ingenuity,3)
# (rail,3)
# (bubble,3)
# (ceos,3)
# (dealing,3)
# (unnecessary,3)
# (straight,3)
# (covered,3)
# (plans,3)
# (hated,3)
# (results,3)
# (otherwise,3)
# (privacy,3)
# (inherited,3)
# (syrian,3)
# (country's,3)
# (tackle,3)
# (proven,3)
# (accept,3)
# (unemployed,3)
# (senior,3)
# (doubt:,3)
# (despite,3)
# (enemies,3)
# (weight,3)
# (setbacks,3)
# (laying,3)
# (lowest,3)
# (several,3)
# (siemens,3)
# (decide,3)
# (layoffs,3)
# (july,3)
# (asian,3)
# (selling,3)
# (you'll,3)
# (wouldn't,3)
# (produce,3)
# (1990s,3)
# (colombia,3)
# (40,3)
# (employment,3)
# (unified,3)
# (appointed,3)
# (i'd,3)
# (test,3)
# (calling,3)
# (deny,3)
# (spill,3)
# (brain,3)
# (grit,3)
# (pennsylvania,3)
# (struggles,3)
# (permanent,3)
# (turned,3)
# (brian,3)
# (earning,3)
# (flag,3)
# (aid,3)
# (joe,3)
# (newtown,3)
# (israel,3)
# (shows,3)
# (lined,3)
# (bomb,3)
# (strongly,3)
# (ronald,3)
# (feet,3)
# (upgrade,3)
# (amanda,3)
# (charged,3)
# (disease,3)
# (hospital,3)
# (automakers,3)
# (terrorist,3)
# (poised,3)
# (qaeda's,3)
# (pride,3)
# (allen,3)
# (elections,3)
# (road,3)
# (9/11,3)
# (areas,3)
# (doubt,3)
# (truly,3)
# (arabian,3)
# (supports,3)
# (nine,3)
# (contain,3)
# (supported,3)
# (systems,3)
# (2,3)
# (coalition,3)
# (father,3)
# (opening,3)
# (amount,3)
# (encourages,3)
# (hole,3)
# (u.s,3)
# (promises,3)
# (iraqi,3)
# (engineers,3)
# (treatment,3)
# (severe,3)
# (childhood,3)
# (behavior,3)
# (quickly,3)
# (friend,3)
# (limits,3)
# (innocent,3)
# (professionals,3)
# (lady,3)
# (winning,3)
# (generation's,3)
# (compromise,3)
# (heroes,3)
# (f,3)
# (maybe,3)
# (cold,3)
# (unprecedented,3)
# (vulnerable,3)
# (dangerous,3)
# (met,3)
# (fee,3)
# (reagan,3)
# (yemen,3)
# (consumed,3)
# (households,3)
# (brave,3)
# (proposal,3)
# (diplomatic,3)
# (centuries,3)
# (puts,3)
# (sold,3)
# (bullet,3)
# (bureaucracy,3)
# (travel,3)
# (argue,3)
# (differently,3)
# (region,3)
# (africa,3)
# (senator,3)
# (facing,3)
# (sit,3)
# (labs,3)
# (sending,3)
# (personal,3)
# (numbers,3)
# (fast,3)
# (propose,3)
# (guarantee,3)
# (pain,3)
# (strengthening,3)
# (institution,3)
# (secretary,3)
# (card,3)
# (lands,3)
# (design,3)
# (equip,3)
# (ultimately,3)
# (sometimes,3)
# (outdated,3)
# (principal,3)
# (california,3)
# (furniture,3)
# (capabilities,3)
# (extremism,3)
# (dropped,3)
# (raised,3)
# (officials,3)
# (rubble,3)
# (refuse,3)
# (firefighters,3)
# (panama,3)
# (consistent,3)
# (advance,3)
# (thinking,3)
# (independence,3)
# (onto,3)
# (modest,3)
# (rich,3)
# (skeptical,3)
# (costly,3)
# (15,3)
# (millionaires,3)
# (master,3)
# (conditions,3)
# (equality,3)
# (prices,3)
# (submit,3)
# (beat,3)
# (pathway,3)
# (tech,3)
# (groups,3)
# (lets,3)
# (feed,3)
# (proportion,3)
# (resolve,3)
# (bryan,3)
# (this:,3)
# (absolutely,3)
# (germany,3)
# (world-class,3)
# (raising,3)
# (respond,3)
# (probably,3)
# (children's,3)
# (cities,3)
# (thriving,3)
# (collapse,3)
# (fifteen,3)
# (messy,3)
# (short-term,3)
# (truth,3)
# (annual,3)
# (condition,3)
# (saying,3)
# (meeting,3)
# (uninsured,3)
# (notion,3)
# (india,3)
# (decent,3)
# (wasteful,3)
# (blows,3)
# (ford,3)
# (delay,3)
# (counterterrorism,3)
# (bridge,3)
# (broadband,3)
# (customers,3)
# (hard-working,3)
# (biofuels,3)
# (killed,3)
# (50,3)
# (protecting,3)
# (ensures,3)
# (worthy,3)
# (strongest,3)
# (jackie,3)
# (easier,3)
# (repair,3)
# (view,3)
# (nobody,3)
# (acted,3)
# (wonder,3)
# (pre-k,3)
# (fundamental,3)
# (18,3)
# (given,3)
# (scientists,3)
# (corruption,3)
# (doubled,3)
# (leader,3)
# (suggested,3)
# (transformation,3)
# (joined,3)
# (march,3)
# ($10,000,3)
# (95%,3)
# (happened,3)
# (usher,3)
# (inequality,3)
# (whole,3)
# (questions,3)
# (prevents,3)
# (moved,3)
# (legal,3)
# (lenders,3)
# (year's,3)
# (jeopardize,3)
# (slow,3)
# (everybody,3)
# (contribute,3)
# (telling,3)
# (avoid,3)
# (constitution,3)
# (consider,3)
# (blueprint,3)
# (online,3)
# (holding,3)
# (pakistan,3)
# (showing,3)
# (reaching,3)
# (tunisia,3)
# (engage,3)
# (succeeded,3)
# (carry,3)
# (really,3)
# (revolution,3)
# (size,3)
# (stands,3)
# (forced,3)
# (electricity,3)
# (milk,3)
# (effective,3)
# (votes,3)
# (empty,3)
# (financing,3)
# (burdens,3)
# (early,3)
# (hurt,3)
# (modern,3)
# (commerce,3)
# (page,3)
# (overwhelming,3)
# (coal,3)
# (solution,3)
# (hardship,3)
# (engagement,3)
# (sandy,3)
# (deeper,3)
# (black,3)
# (manufacture,3)
# (midst,3)
# (competitive,3)
# (efficiency,3)
# (armed,3)
# (productive,3)
# (pacific,3)
# (pushed,3)
# (earmark,3)
# (advantage,3)
# (decency,3)
# (checks,3)
# (connected,3)
# (subsidizing,3)
# (alive,3)
# (gather,3)
# (batteries,3)
# (cells,3)
# (ours,3)
# (above,3)
# (breakthroughs,3)
# (repeat,3)
# (saved,3)
# (army,3)
# (historic,3)
# (wave,3)
# (contentious,3)
# (innovative,3)
# (ran,3)
# (computer,3)
# (grants,3)
# (nation's,3)
# (news,3)
# (drilling,3)
# (buildings,3)
# (entrepreneur,3)
# (fairness,3)
# (provided,3)
# (summit,3)
# (center,3)
# (doctor,3)
# (hours,3)
# (1,3)
# (immigrants,3)
# (belief,3)
# (opinions,3)
# (monthly,3)
# (drives,3)
# (bet,3)
# (mountain,3)
# (guests,3)
# (subsidies,3)
# (wasn't,2)
# (requiring,2)
# (she's,2)
# (risky,2)
# (records,2)
# (plus,2)
# (grant,2)
# (common-sense,2)
# ($4,2)
# (safely,2)
# (fastest-growing,2)
# (backed,2)
# (download,2)
# (sharp,2)
# (it;,2)
# (lender,2)
# (issuing,2)
# (foundations,2)
# (resource,2)
# (upholding,2)
# (charlotte,2)
# (defining,2)
# (weren't,2)
# (workplace,2)
# (fail,2)
# (table,2)
# (reflects,2)
# (leaves,2)
# (gi,2)
# (precious,2)
# (tirelessly,2)
# (accounts,2)
# (emphasis,2)
# (muslims,2)
# (robert,2)
# (everywhere,2)
# (baby,2)
# (invent,2)
# (reinvented,2)
# (classes,2)
# (1st,2)
# (twice,2)
# (reminded,2)
# (opposition,2)
# (finance,2)
# (finished,2)
# (buffett,2)
# (tear,2)
# (americans',2)
# (risks,2)
# (inside,2)
# (inventors,2)
# (affairs,2)
# (anxieties,2)
# (relieve,2)
# (ii,2)
# (landed,2)
# (extremists,2)
# (footing,2)
# (disclose,2)
# (map,2)
# (using,2)
# (likely,2)
# (details,2)
# (jewish,2)
# (nato,2)
# (classmates,2)
# (framework,2)
# (countless,2)
# (confusing,2)
# (comrades,2)
# (subsidized,2)
# (streamline,2)
# (bear,2)
# (operations,2)
# (optimism,2)
# (abuse,2)
# (experience,2)
# (replace,2)
# (capital,2)
# (rely,2)
# (citizen,2)
# (preparing,2)
# (waters,2)
# (precisely,2)
# (understanding,2)
# (holds,2)
# (battlefield,2)
# (declared,2)
# (attracts,2)
# (deep,2)
# (tragedy,2)
# (uphold,2)
# (beliefs,2)
# (gains,2)
# (pursuit,2)
# (serves,2)
# (expelling,2)
# (internet;,2)
# (plenty,2)
# (connect,2)
# (commander-in-chief,2)
# (buying,2)
# (sat,2)
# (victory,2)
# (b,2)
# (locked,2)
# (kill,2)
# (total,2)
# (fire,2)
# (mothers,2)
# (homeowner,2)
# (requires,2)
# (missile,2)
# (peacefully,2)
# (imagine,2)
# (walked,2)
# (near,2)
# (crack,2)
# (network,2)
# (centers,2)
# (chicago,2)
# (principle,2)
# (seeking,2)
# (enshrined,2)
# (momentum,2)
# (rival,2)
# (japan,2)
# (founding,2)
# (drove,2)
# (computers,2)
# (discipline,2)
# (marriage,2)
# (omaha,2)
# (reckless,2)
# (case,2)
# (declare,2)
# (chose,2)
# ($2,2)
# (offshore,2)
# (simple:,2)
# (losing,2)
# (inspire,2)
# (answer,2)
# (preserve,2)
# (detention,2)
# (consumer,2)
# (perfectly,2)
# (journey,2)
# (syria,2)
# (balance,2)
# (threatens,2)
# (february,2)
# (sides,2)
# (positioned,2)
# (80,2)
# (shadow,2)
# (overcome,2)
# (causes,2)
# (boldly,2)
# (excuses,2)
# (reversed,2)
# (endures,2)
# (turns,2)
# (broad-based,2)
# (closer,2)
# (fuel-efficient,2)
# (usual,2)
# (cap,2)
# (strides,2)
# (principled,2)
# (digital,2)
# (stagnant,2)
# (drug,2)
# (illusions,2)
# (followed,2)
# (shuttered,2)
# (captured,2)
# (background,2)
# (deductions,2)
# (describes,2)
# (somalia,2)
# (assembly,2)
# (healing,2)
# (guide,2)
# (cabinet,2)
# (reality,2)
# (graduation,2)
# (miners,2)
# (parent,2)
# (gut,2)
# (ended,2)
# (regardless,2)
# (behalf,2)
# (translate,2)
# (strike,2)
# (korean,2)
# (lowers,2)
# (low,2)
# (educating,2)
# (commitments,2)
# (requests,2)
# (michigan,2)
# (24,2)
# (shop,2)
# (performance,2)
# (enormous,2)
# (transparent,2)
# (discoveries,2)
# (relationship,2)
# (large-scale,2)
# (market-based,2)
# (earmarks,2)
# (securing,2)
# (homework,2)
# (post,2)
# (eliminated,2)
# (addressing,2)
# (grateful,2)
# (planted,2)
# (report,2)
# (night,2)
# (negotiate,2)
# (alike,2)
# (apple,2)
# (plots,2)
# (views,2)
# (g-20,2)
# (afghans,2)
# (produced,2)
# (violations,2)
# (affected,2)
# (bets,2)
# (late,2)
# (criminals,2)
# (highways,2)
# (voice,2)
# (balanced,2)
# (barriers,2)
# (arguments,2)
# (loved,2)
# (penny,2)
# (classrooms,2)
# (overnight,2)
# (check,2)
# (tom,2)
# (vision,2)
# (operatives,2)
# (wounded,2)
# (locate,2)
# (term,2)
# (bucks,2)
# (budgets,2)
# (inspiration,2)
# (youngest,2)
# (complex,2)
# (divisions,2)
# (nest,2)
# (welcomed,2)
# (non-partisan,2)
# (parents',2)
# (benefited,2)
# (sidelines,2)
# (now:,2)
# (protected,2)
# (consequences,2)
# (halfway,2)
# (yesterday,2)
# (raleigh,2)
# (among,2)
# (hardships,2)
# (moves,2)
# (sputnik,2)
# (protects,2)
# (preexisting,2)
# (acres,2)
# (faces,2)
# (roaring,2)
# (clearly,2)
# (wealthy,2)
# (event,2)
# (extraordinary,2)
# (periods,2)
# (laden,2)
# ($10.10,2)
# (meantime,2)
# (bay,2)
# (vigilant,2)
# (aging,2)
# (dedication,2)
# (scope,2)
# (firm,2)
# (final,2)
# (trapped,2)
# (asthma,2)
# (backs,2)
# (rather,2)
# (healthier,2)
# (corrosive,2)
# (remnants,2)
# (flowing,2)
# (perpetual,2)
# (vast,2)
# (honor,2)
# (55,2)
# (responsibly,2)
# (renewal,2)
# (grid,2)
# (poor,2)
# (asia-pacific,2)
# (driven,2)
# (20,2)
# (odds,2)
# (extreme,2)
# (relent,2)
# (prosperity;,2)
# (forgiven,2)
# (giffords,2)
# (courses,2)
# (sitting,2)
# (wasted,2)
# (family's,2)
# (electronic,2)
# (surplus,2)
# (2008,2)
# (invested,2)
# (creativity,2)
# (remaining,2)
# (defending,2)
# (outlined,2)
# (stairs,2)
# (child's,2)
# (refinancing,2)
# (declined,2)
# (ports,2)
# (english,2)
# (mind,2)
# (exactly,2)
# (realize,2)
# (protections,2)
# (violate,2)
# (discretionary,2)
# (generations;,2)
# (roofing,2)
# (saving,2)
# (governance,2)
# (counter,2)
# (preventive,2)
# (entering,2)
# (eyes,2)
# (options,2)
# ("they,2)
# (andra,2)
# (proved,2)
# (mostly,2)
# (talking,2)
# (day's,2)
# (surgery,2)
# (tested,2)
# (madame,2)
# (careers,2)
# (earliest,2)
# (irresponsible,2)
# (disappear,2)
# (brings,2)
# (lawyers,2)
# (toward,2)
# (competitors,2)
# (havens,2)
# (levels,2)
# (official,2)
# (drought,2)
# (adversaries,2)
# (investors,2)
# (trained,2)
# (taliban,2)
# (busy,2)
# (bottom,2)
# (hardest-hit,2)
# (loves,2)
# (liberal,2)
# (chile,2)
# (frustrating,2)
# (rebounding,2)
# (redesign,2)
# (write,2)
# (firmly,2)
# (mayors,2)
# (constructing,2)
# (seeing,2)
# (agency,2)
# (grueling,2)
# (bonuses,2)
# (repeal,2)
# (newspaper,2)
# (burma,2)
# (rejoin,2)
# (elements,2)
# (decides,2)
# (farmer,2)
# (kathy,2)
# (quick,2)
# (enlisting,2)
# ($3,000,2)
# (simplify,2)
# (punishing,2)
# (george,2)
# (all-in,2)
# (gabby,2)
# (invented,2)
# (struggled,2)
# (doubts,2)
# (extended,2)
# (formed,2)
# (steal,2)
# (muslim,2)
# (birth,2)
# (lowering,2)
# (target,2)
# (school;,2)
# (ties,2)
# (educational,2)
# (job-creating,2)
# (forget,2)
# (voting,2)
# (renew,2)
# (citizens:,2)
# (they'd,2)
# (circumstance,2)
# (false,2)
# (seems,2)
# (resilience,2)
# ($100,2)
# (first-class,2)
# (spring,2)
# (myra,2)
# (forsyth,2)
# (mental,2)
# (faced,2)
# (deduction,2)
# (realizing,2)
# (corner,2)
# (spends,2)
# (untouched,2)
# (trend,2)
# (100,000,2)
# (they'll,2)
# (canal,2)
# (youngstown,2)
# (match,2)
# (oak,2)
# (coalitions,2)
# (watch,2)
# (summon,2)
# (belong,2)
# (boost,2)
# (focused,2)
# (boots,2)
# (luxury,2)
# (chair,2)
# (slash,2)
# (rebuilt,2)
# (98,2)
# (terrorism,2)
# (promised,2)
# (lock,2)
# (flying,2)
# (reasons,2)
# (repeat:,2)
# (together;,2)
# (prosper,2)
# (argument,2)
# (accountants,2)
# (agencies,2)
# (hiring,2)
# (indeed,2)
# (stockpiles,2)
# (returned,2)
# (popular,2)
# (egg,2)
# (steel,2)
# (haiti,2)
# (backgrounds,2)
# (bankruptcy,2)
# (perhaps,2)
# (shrinking,2)
# (quitting,2)
# (solid,2)
# (drugs,2)
# (storm,2)
# (embraced,2)
# (involve,2)
# (treaty,2)
# (bin,2)
# (claims,2)
# (houses,2)
# (dad,2)
# (palestinians,2)
# (undocumented,2)
# (spread,2)
# (crushing,2)
# (lend,2)
# (dominated,2)
# (emerged,2)
# (pet,2)
# (itself,2)
# (beach,2)
# (tyranny,2)
# (opens,2)
# (exist,2)
# (cases,2)
# (crumbling,2)
# (generals,2)
# (deposits,2)
# (unity,2)
# (rise,2)
# (2010,2)
# (moral,2)
# (restoring,2)
# (competent,2)
# (talents,2)
# (limit,2)
# (nick,2)
# (expensive,2)
# (pose,2)
# (it:,2)
# (room,2)
# (material,2)
# (driving,2)
# (bought,2)
# (coverage;,2)
# (shifts,2)
# (rarely,2)
# (penalty,2)
# (born,2)
# (european,2)
# (universal,2)
# (marching,2)
# (upward,2)
# (cyber,2)
# (endure,2)
# (penalties,2)
# (diplomats,2)
# (unfinished,2)
# (everyone's,2)
# (federally-funded,2)
# (large,2)
# (actually,2)
# (pledged,2)
# (isolated,2)
# (evidence,2)
# (google,2)
# (open-ended,2)
# (acts,2)
# (environment,2)
# (skill,2)
# (visit,2)
# (you've,2)
# (announced,2)
# (revive,2)
# (stabilized,2)
# (demanding,2)
# (lifting,2)
# (concrete,2)
# (desiline,2)
# (moments,2)
# (unable,2)
# (themselves;,2)
# (events,2)
# (john's,2)
# (conservative,2)
# (vacant,2)
# (immediate,2)
# (supply,2)
# (shale,2)
# (consolidate,2)
# (offered,2)
# (highway,2)
# (recognition,2)
# (eye,2)
# (area,2)
# (discrimination,2)
# (floods,2)
# (1,000,2)
# (identified,2)
# (missions:,2)
# (firms,2)
# (reject,2)
# (disaster,2)
# (hopes,2)
# (100,2)
# (va,2)
# (senators,2)
# (designed,2)
# (sustainable,2)
# (pad,2)
# (having,2)
# (finishing,2)
# (happens,2)
# (slashing,2)
# (plunged,2)
# (boards,2)
# (written,2)
# (interstate,2)
# (certainly,2)
# (darkness,2)
# (torture,2)
# (obesity,2)
# (remsburg,2)
# (crimes,2)
# (assure,2)
# (shore,2)
# (guarantees,2)
# (suffering,2)
# (women;,2)
# (filling,2)
# (facilities,2)
# (payroll,2)
# (federally-financed,2)
# (talented,2)
# (minneapolis,2)
# (philosophical,2)
# (somewhere,2)
# (promotion,2)
# (minds,2)
# (soldiers,2)
# (debated,2)
# (directing,2)
# (sixty,2)
# (skyrocketing,2)
# (central,2)
# (plays,2)
# (politicians,2)
# (hesitate,2)
# (verge,2)
# (twelve,2)
# (moon,2)
# (finances,2)
# (theirs,2)
# (key,2)
# (steadily,2)
# (pre-existing,2)
# (tomorrow's,2)
# (defenses,2)
# (additional,2)
# ("i'm,2)
# (failed,2)
# (outside,2)
# (yourself,2)
# (proving,2)
# (settle,2)
# (guantanamo,2)
# (escape,2)
# (finding,2)
# (wildfires,2)
# (hurting,2)
# (broke,2)
# (trains,2)
# (sons,2)
# (concerns,2)
# (bailouts,2)
# (uncertain,2)
# (attorneys,2)
# (mindful,2)
# (forms,2)
# (boss,2)
# (deploy,2)
# (dependence,2)
# (mali,2)
# (crowd,2)
# (ohio,2)
# (removing,2)
# (budged,2)
# (winner,2)
# (advocate,2)
# (miami,2)
# (collapsed,2)
# (cast,2)
# (answers,2)
# (gain,2)
# (grew,2)
# (launchers,2)
# (congressional,2)
# (organization,2)
# (all-of-the-above,2)
# (negotiating,2)
# (degrees,2)
# (principals,2)
# (contributions,2)
# (pledge,2)
# (ladders,2)
# (initiatives,2)
# (steve,2)
# (facts,2)
# (trading,2)
# (institute,2)
# (openings,2)
# (account,2)
# (patient,2)
# (treated,2)
# (increasing,2)
# (owe,2)
# (crossings,2)
# (deportation,2)
# (inspections,2)
# (willingness,2)
# (turbine,2)
# (religion,2)
# (height,2)
# (generate,2)
# (recklessness,2)
# (unwarranted,2)
# (reinvent,2)
# (claimed,2)
# (video,2)
# (gaps,2)
# (alliance,2)
# (marines,2)
# (families;,2)
# (represents,2)
# (rallied,2)
# (placed,2)
# (reforming,2)
# (damage,2)
# (remind,2)
# (she'd,2)
# (retire,2)
# (missions,2)
# (expanded,2)
# (trajectory,2)
# (approved,2)
# (deals,2)
# (rock,2)
# (fulfilled,2)
# (70,000,2)
# (democrat,2)
# (response,2)
# (pr,1)
# (transitions,1)
# (mattered,1)
# (urging,1)
# (shaping,1)
# (surge,1)
# (envelope,1)
# (lower-wage,1)
# (merge,1)
# (gap,1)
# (twenty-three,1)
# (crying,1)
# (warfare,1)
# (hold?,1)
# (stayed,1)
# (whims,1)
# (offering,1)
# (substitute,1)
# (pilot,1)
# (bush's,1)
# (ally,1)
# ($400,1)
# (shut,1)
# (pretend,1)
# (completing,1)
# (reportedly,1)
# (well-being,1)
# (growth?,1)
# (cyberattacks,1)
# (accessing,1)
# (cheers,1)
# (freer,1)
# (ourselves.",1)
# (dangers,1)
# (free.",1)
# (thus,1)
# (33,1)
# (plug-in,1)
# (floodgates,1)
# (mistakes;,1)
# (chosen,1)
# (heroic,1)
# (compounded,1)
# (drew,1)
# (fourth,1)
# ("u.s.a.!,1)
# (lived,1)
# (finalized,1)
# (profit,1)
# (other's,1)
# (care;,1)
# (murderer,1)
# (builders,1)
# (sheets,1)
# (deterrents,1)
# (proper,1)
# (contact,1)
# (overwhelmingly,1)
# (him:,1)
# (hits,1)
# (turmoil,1)
# (rolled,1)
# (projected,1)
# (retiring,1)
# (hindu,1)
# (looks,1)
# (trans-pacific,1)
# (vets,1)
# (correcting,1)
# (salvador,1)
# (decimated,1)
# (park,1)
# (worried,1)
# (fine,1)
# (develops,1)
# (yachts,1)
# (phony,1)
# (managers,1)
# (virtually,1)
# (obstruct,1)
# (names,1)
# (stresses,1)
# (gold,1)
# (dictate,1)
# (fears;,1)
# (cook,1)
# (yours,1)
# (mission:,1)
# (sharing,1)
# (achievement;,1)
# (focuses,1)
# (60,000,1)
# (litigation,1)
# (panels;,1)
# (administrative,1)
# (choked,1)
# (reminds,1)
# (nineteen,1)
# (philanthropists,1)
# (blood,1)
# (cancel,1)
# (rancorous,1)
# (nave,1)
# (policy-making,1)
# (remote,1)
# (pentagon,1)
# (back?,1)
# (refused,1)
# (visited,1)
# (nurses,1)
# (utilities,1)
# (remembered.",1)
# (creed;,1)
# (tone,1)
# ("lost,1)
# (harm,1)
# (reached,1)
# (money.",1)
# (dillon,1)
# (for?,1)
# (toil,1)
# (numbing,1)
# (mutual,1)
# (encouraging,1)
# (congratulating,1)
# (four-year,1)
# (commonwealth's,1)
# (jobi,1)
# (devised,1)
# (solar;,1)
# (outcome,1)
# (prudent,1)
# (abess,1)
# (assemble,1)
# (fever,1)
# (continuing,1)
# (rumors,1)
# (flawlessly,1)
# (imported,1)
# (legally,1)
# (fragile,1)
# (apply,1)
# (clerksthey,1)
# (off-ramp,1)
# (15,000,1)
# (steals,1)
# (participate,1)
# (strained,1)
# (pay-as-you-go,1)
# (chip,1)
# (easy,",1)
# (belts,1)
# (isn't;,1)
# (bang,1)
# (brink,1)
# (defeated,1)
# ("none,1)
# (112th,1)
# (re-imagined,1)
# (nowhere,1)
# (dawn,1)
# (jumpstart,1)
# (americans?,1)
# (hadiya,1)
# (decency;,1)
# (spoke,1)
# (shifting,1)
# (slows,1)
# (trial,1)
# (israel's,1)
# (gates,1)
# (raid,1)
# (revolutions,1)
# (randolph,1)
# (easy.",1)
# (enforced,1)
# (contributing,1)
# (gloss,1)
# (counterfeit,1)
# (controversy,1)
# (father's,1)
# (punch,1)
# (well-off,1)
# (stalemate,1)
# (he'd,1)
# (judgment,1)
# (noisy,1)
# (whenever,1)
# (reliable,1)
# (sixteen,1)
# (harm's,1)
# (200,000,1)
# (rule:,1)
# (u.s.a.!,1)
# (kentucky's,1)
# (matters,1)
# (scranton,1)
# (equation,1)
# (mandate,1)
# (crisis;,1)
# (talent,1)
# (larger;,1)
# (berlin,1)
# (boosted,1)
# (destructive,1)
# (specializes,1)
# (hired,1)
# (wise,1)
# (salute,1)
# (income;,1)
# (somehow,1)
# (funded,1)
# (volunteer,1)
# (tempting,1)
# (purchases,1)
# (bus,1)
# (crossing,1)
# (unleash,1)
# (memorize,1)
# (throng,1)
# (differing,1)
# (lobbyists;,1)
# (research;,1)
# (tracks,1)
# (handouts,1)
# (superstorm,1)
# (evolving,1)
# (bump,1)
# (11th,1)
# (by;,1)
# (slightly,1)
# (affordability,1)
# (200,1)
# (unused,1)
# (bowl,1)
# (truths,1)
# (borne,1)
# (starters,1)
# (life,",1)
# (tremendous,1)
# (lesson,1)
# (tranquility,1)
# (fast-changing,1)
# (legislatures,1)
# (terror,1)
# (congressmen,1)
# (feeling,1)
# (stress,1)
# (hinder,1)
# (god-given,1)
# (obligation,1)
# (discovery,1)
# (joining,1)
# (sanchez,1)
# (work;,1)
# (inefficient,1)
# (documents,1)
# (vocational,1)
# (great;,1)
# (nationality,1)
# (romney,1)
# (bankers,1)
# (experienced,1)
# (purchasing,1)
# (gangs,1)
# (deepened,1)
# (tight,1)
# (navy,1)
# (extra,1)
# (billionaire,1)
# (ready-to-be-filled,1)
# (chilean,1)
# (airplane,1)
# (substantial,1)
# (die,1)
# (andrews,1)
# (imperative,1)
# (offices;,1)
# (ineffective,1)
# (disable,1)
# (protectionism,1)
# (rocked,1)
# (cleared,1)
# (surrender,1)
# (neighborsi,1)
# (ambitions,1)
# (reductions,1)
# (long-time,1)
# (lieutenants,1)
# ($2000,1)
# (americans;,1)
# (awhile,1)
# (stopping,1)
# (homeownership,1)
# (fraction,1)
# (2035,1)
# (warriors;,1)
# (withfarmers,1)
# (inspired,1)
# (meets,1)
# (prosecute,1)
# (review,1)
# (across-the-board,1)
# (degree.",1)
# (officer,1)
# (anniversary,1)
# (passion;,1)
# (targeted,1)
# (driveways,1)
# (data,1)
# (sexual,1)
# (tide,1)
# (necessary;,1)
# (selfish,1)
# (town's,1)
# (double-down,1)
# (washed,1)
# (tokyo,1)
# (payoffs,1)
# (us,",1)
# (becomes,1)
# (moms,1)
# (determining,1)
# (alzheimer's;,1)
# (list,1)
# (fcc,1)
# (egypt;,1)
# (signs,1)
# (scrambling,1)
# (partisanship,1)
# (bystander,1)
# (rangoon,1)
# (conducting,1)
# (extracted,1)
# (soviets;,1)
# (curriculums,1)
# ("something,1)
# (filled,1)
# ($60,1)
# (will.",1)
# (payday,1)
# (low-income,1)
# (undoes,1)
# (misty,1)
# (american.",1)
# (salaries,1)
# (solutions,1)
# (working-class,1)
# (milwaukee,1)
# (theaters,1)
# (unsafe,1)
# (constructed,1)
# (coast,1)
# (bashing,1)
# (400,000,1)
# ("my,1)
# (2015,1)
# (indiana,1)
# (fossil,1)
# (cynical?,1)
# (colors,1)
# (equipping,1)
# (republic,1)
# (intel,1)
# (notice:,1)
# (circumstances,1)
# (branch,1)
# (form,1)
# (6th,1)
# (arbitrary,1)
# (murdered,1)
# (aids-free,1)
# (assistant,1)
# (tied,1)
# (duty,1)
# (proposal:,1)
# (teddy,1)
# (beside,1)
# (misfortune,1)
# ("d.",1)
# (responded,1)
# (investment;,1)
# (rigged,1)
# (crashed,1)
# (concentrate,1)
# (runaround,1)
# (undo,1)
# (guaranteed,1)
# (daunting,1)
# (shelves,1)
# (transfers,1)
# (aligned,1)
# (intense,1)
# (magnitude,1)
# (others;,1)
# (yearns,1)
# (body,1)
# (honestly,1)
# (operate,1)
# (threatened,1)
# (seeds,1)
# (regulators,1)
# (movie,1)
# (flipped,1)
# (thrive,1)
# (dr,1)
# (knowledge,1)
# (function,1)
# (clock,1)
# (lightweight,1)
# (broad,1)
# (associate,1)
# (guaranteeing,1)
# (chemical,1)
# (transform,1)
# (interior,1)
# (preside,1)
# (haven,1)
# (tax-free,1)
# (airports,1)
# (smartphones,1)
# (morning,1)
# (salmon,1)
# (estiven,1)
# (incomplete,1)
# (school's,1)
# (morale,1)
# (unstable,1)
# (pavement,1)
# (provides,1)
# (cincinnati,1)
# (limited,1)
# (self-government,1)
# ($14,500,1)
# (israelis,1)
# (stimulus,1)
# (media,1)
# (occasional,1)
# (unpopular,1)
# (contractors,1)
# ($1,500,1)
# (messages,1)
# (blacksburg,1)
# (discourage,1)
# (joint,1)
# (bans,1)
# (bundle,1)
# (hands-on,1)
# (chaos,1)
# (blocked,1)
# (weather,1)
# (people;,1)
# ("thank,1)
# (reduced,1)
# (vaccines,1)
# (short-cuts,1)
# (allentown,1)
# (riddled,1)
# (delivered,1)
# (eradicate,1)
# (surpluses,1)
# (neighborhood,1)
# (restored,1)
# (peril,1)
# (energetx,1)
# ("god,1)
# (sleepless,1)
# (openly;,1)
# (president's,1)
# (door,1)
# (revealed,1)
# (essence,1)
# (farm,1)
# (waves,1)
# (himself,1)
# (solving,1)
# (shun,1)
# (improvement,1)
# (twilight,1)
# (drug-resistant,1)
# (nation;,1)
# (waving,1)
# (organizations,1)
# (meltdown,1)
# (procedures,1)
# (session,1)
# (express,1)
# (channels,1)
# (decision-making,1)
# (destined,1)
# (immediately,1)
# (brooklyn,1)
# (stockpile,1)
# (bag,1)
# (staffing,1)
# (airline,1)
# (proudest,1)
# (97,1)
# (governments,1)
# (permits,1)
# (out-teach,1)
# (window,1)
# (employees',1)
# (ballot,1)
# (survival,1)
# (secondary,1)
# (heavily,1)
# (dollars',1)
# (productivity,1)
# (shapes,1)
# (rejects,1)
# (re-litigating,1)
# (board,1)
# (lifeblood,1)
# (preventable,1)
# (attorney,1)
# (revitalizing,1)
# (demars,1)
# (christians,1)
# (dig,1)
# (rush,1)
# (owning,1)
# (fate,1)
# (mailed,1)
# (imagination,1)
# (chiefs,1)
# (biotechnology,1)
# (paint,1)
# (uncertain;,1)
# (control;,1)
# (reason:,1)
# (wait?,1)
# (favorite,1)
# (90%,1)
# (restructure,1)
# (educators,1)
# (mismanagement,1)
# (77,1)
# (demonstrate,1)
# (realities,1)
# (dumping,1)
# (april,1)
# (repairs,1)
# (panel,1)
# (nonprofits,1)
# (fascism,1)
# (entrusted,1)
# (stitched,1)
# (modeled,1)
# (praying,1)
# (abraham,1)
# (giveaways,1)
# (badly,1)
# (push,1)
# (dishes,1)
# (beacon,1)
# (drawn,1)
# (embarrassment,1)
# (touched,1)
# (noticed,1)
# (gregg,1)
# (discussion,1)
# (withstand,1)
# (kentucky,1)
# (troops',1)
# (fiasco?,1)
# (seats,1)
# (arm,1)
# (miles,1)
# (harness,1)
# (opponents,1)
# (wives,1)
# (gravest,1)
# (drawing,1)
# ("are,1)
# (drawdown,1)
# (2013,1)
# (exceed,1)
# (cleveland,1)
# (crippling,1)
# (3.5,1)
# (cultural,1)
# (trimmed,1)
# (secret,1)
# (mapping,1)
# (expansion;,1)
# (cobra;,1)
# (roofers,1)
# (robert's,1)
# (stripes,1)
# (so-called,1)
# (pump,1)
# ("this,1)
# (elyria,1)
# ($20,1)
# (yesterday's,1)
# (26,1)
# (enterprise;,1)
# (james,1)
# (seals,1)
# (surrounding,1)
# (readiness,1)
# (contentious;,1)
# (triumphed,1)
# (disagreements;,1)
# (quicken,1)
# (advancement,1)
# (caring,1)
# (backwards,1)
# (resolved,1)
# (neighbor,1)
# (servants,1)
# (coaching,1)
# (attention,1)
# (1.5,1)
# (dump,1)
# (allowance,1)
# (quicker,1)
# (secure;,1)
# (islamic,1)
# (shopping,1)
# (jim,1)
# (cycle,1)
# ("now,1)
# (valuable,1)
# (globe;,1)
# (possess,1)
# (boy,1)
# (ticked,1)
# (honorable,1)
# (iowa,1)
# (america:,1)
# (harming,1)
# (inner-cities,1)
# (pat-down,1)
# (prove,1)
# (paper,1)
# (mayor,1)
# (8-year,1)
# (chrysler,1)
# (heat,1)
# (hidden,1)
# ("what,1)
# (eased,1)
# (advice,1)
# (structurally,1)
# (unfortunately,1)
# (achievements,1)
# (conflict,1)
# (prefer,1)
# (history's,1)
# (halted,1)
# (triple,1)
# (all-out,1)
# (merits,1)
# (candidates,1)
# (frozen,1)
# (magnet,1)
# (decade",1)
# (grandfather,1)
# (widely,1)
# (coma,1)
# (lawsuits,1)
# (lobbying,1)
# (excluded,1)
# (schoolyard,1)
# (tougher,1)
# (ira,1)
# (adjustments,1)
# (scale,1)
# (saves,1)
# (meetings,1)
# (reverse,1)
# (affects,1)
# (demanded,1)
# (syria's,1)
# (equivalent,1)
# (re-design,1)
# (shelley,1)
# (blue,1)
# (continent,1)
# (frequent,1)
# (slip,1)
# (before;,1)
# (apprenticeships,1)
# (unites,1)
# (acting,1)
# (highs;,1)
# (frustrations,1)
# (menchu,1)
# (routes,1)
# (reaffirm,1)
# (gulf,1)
# (beshear,1)
# (mechanic,1)
# (remarkable,1)
# (facebook,1)
# (convinces,1)
# (avert,1)
# (motors,1)
# (hire:,1)
# (exporters,1)
# (birthdays,1)
# (hard;,1)
# (conscience,1)
# ($8,1)
# (soranno,1)
# (selflessness,1)
# (blow,1)
# (rehab,1)
# (handheld,1)
# (deadline,1)
# (click,1)
# (self,1)
# (myself.",1)
# (distrust,1)
# (dare,1)
# (sabotage,1)
# (dozen,1)
# (exercise,1)
# (dictatorship,1)
# (someday,1)
# (decided,1)
# (inauguration,1)
# (society,1)
# (33,000,1)
# (hatch,1)
# (elementary,1)
# (translator,1)
# (reasonable,1)
# (bound,1)
# (rejected,1)
# (tragedies,1)
# (years:,1)
# (urban,1)
# (currently,1)
# (conceive,1)
# (curricula,1)
# (quiet,1)
# (constitutional,1)
# (resumes,1)
# (aurora,1)
# (brothers;,1)
# (tie,1)
# (providers,1)
# (reestablishing,1)
# (gathered,1)
# (taxes?,1)
# (gunman,1)
# (eviction;,1)
# (noise,1)
# (unchecked,1)
# (debt;,1)
# (wished,1)
# (reckoning,1)
# (envy,1)
# (funds,1)
# (pleased,1)
# (gimmicks,1)
# (pause,1)
# (dealt,1)
# (successful,1)
# (changing;,1)
# (automaker;,1)
# (included,1)
# (harmony,1)
# (five-year,1)
# (university,1)
# (disagree,1)
# (reviewing,1)
# (pittsburgh,1)
# (greensburg,1)
# (lie,1)
# (orientation,1)
# (measured,1)
# (transportation,1)
# (28,1)
# (investigating,1)
# (becoming,1)
# (less;,1)
# (mastering,1)
# (unsustainable,1)
# (three-quarters,1)
# (150,1)
# (regulatory,1)
# (promising,1)
# (sustained,1)
# (eat,1)
# (draw,1)
# (safeguard,1)
# (assuring,1)
# (22,1)
# (combating,1)
# (continually,1)
# (right:,1)
# (top-down,1)
# (failing,1)
# (states:,1)
# (99,1)
# (droughts,1)
# (customers',1)
# (harsh,1)
# (invest;,1)
# (investigators,1)
# (sunlight,1)
# (power;,1)
# (shall,1)
# (enriched,1)
# (strong;,1)
# (sprint,1)
# (passions,1)
# (denies,1)
# (messes,1)
# (subject,1)
# (example:,1)
# (redouble,1)
# (risked,1)
# (argued,1)
# (confronted,1)
# (presidency,1)
# (2nd,1)
# (brazil,1)
# (8,1)
# (stamped,1)
# (closed,1)
# (effects,1)
# (well-connected,1)
# (trends,1)
# (pile,1)
# (challenging,1)
# (suffers,1)
# (shelters,1)
# (southern,1)
# (commissions,1)
# (invests,1)
# (voted.",1)
# (scorecard",1)
# (believed:,1)
# (louisville,1)
# (anti-poverty,1)
# (partnering,1)
# (doha,1)
# (living?,1)
# (purpose:,1)
# (violated,1)
# (insider,1)
# (deployments,1)
# (ferret,1)
# (looked,1)
# (devastation,1)
# (american-made,1)
# (hearing,1)
# (liberal;,1)
# (dinner,1)
# (longest,1)
# (simpson-bowles,1)
# (ruin,1)
# (asks,1)
# (graduating,1)
# (anniversaries,1)
# (white;,1)
# (kent,1)
# (walks,1)
# (somebody,1)
# (kids;,1)
# (cashed,1)
# (grinding,1)
# (u.s.a!",1)
# (gps,1)
# (piedmont,1)
# (chance.",1)
# (bio-terrorism,1)
# (thoughts,1)
# (driver,1)
# (bailout,1)
# (worshiping,1)
# (blameless,1)
# (hate,1)
# ($40,1)
# (appreciate,1)
# (pouring,1)
# (embodies,1)
# (negotiated,1)
# (relies,1)
# (booming;,1)
# (removed,1)
# (hide,1)
# (reinvestment,1)
# (stage,1)
# (buyers,1)
# (zero,1)
# (burst,1)
# (performed,1)
# (prohibited,1)
# (ideologies,1)
# (frustrated,1)
# (tennessee,1)
# (reorganization,1)
# (unyielding,1)
# (houser,1)
# (turbines,1)
# (deployed,1)
# (brightest,1)
# (out-educate,1)
# (san,1)
# (physician,1)
# (tutoring,1)
# (creek,1)
# (will",1)
# (sweeping,1)
# (acknowledge,1)
# (qadhafi,1)
# (swifter,1)
# (scorekeeper,1)
# (decisive,1)
# (recruiters,1)
# (sovereign,1)
# (sort,1)
# (exchanges,1)
# (second-place,1)
# (slogan,1)
# (pizza,1)
# (isolation,1)
# (men",1)
# (improved,1)
# (soviet,1)
# (conviction,1)
# (attend,1)
# (harnesses,1)
# (application,1)
# (ribbon-cuttings,1)
# (western,1)
# (aching,1)
# (knock,1)
# (gained,1)
# (subjecting,1)
# (craig,1)
# (books,1)
# (prompting,1)
# (ripped,1)
# (oklahoma,1)
# (re-finance,1)
# (unlock,1)
# (bricks,1)
# (unsolved,1)
# (nationwide,1)
# (first-time,1)
# (year-olds,1)
# (highly-skilled,1)
# (responsive,1)
# (ms,1)
# (christmas,1)
# (expense,1)
# (identities,1)
# (originally,1)
# (hiring;,1)
# (heed,1)
# (fighters,1)
# (sacred,1)
# (aggressive,1)
# (out-compete,1)
# (gift,1)
# (legislator,1)
# (fixed,1)
# (orrin,1)
# (separates,1)
# (flow,1)
# (adds,1)
# (swiftly,1)
# (adapt,1)
# (mistake:,1)
# (reorganize,1)
# (happening,1)
# (striving,1)
# (temperature,1)
# (pray,1)
# (bargain,1)
# (newtons,1)
# (unafraid,1)
# (bankrolled,1)
# (allows,1)
# (candidly,1)
# (ripe,1)
# (suffered,1)
# (75,1)
# (directed,1)
# (battle,1)
# (good-paying,1)
# (scene,1)
# (dissipated,1)
# (doubtful;,1)
# (treat,1)
# (fulfill,1)
# (pristine,1)
# (cause;,1)
# (taxpayer-subsidies,1)
# (spun,1)
# (predicament,1)
# (pretty,1)
# (iranian,1)
# (writ,1)
# (infiltrate,1)
# (teamwork,1)
# (controls,1)
# (epidemic,1)
# (dictator,1)
# (2020,1)
# (resolution,1)
# (petty,1)
# (fatherhood,1)
# (vital,1)
# (april's,1)
# (al-qaeda's,1)
# (patton's,1)
# (developed,1)
# (deter,1)
# (administration's,1)
# (completely,1)
# (trips,1)
# (up?",1)
# (entrenched,1)
# (crystal,1)
# (arizona,1)
# (assad,1)
# (rotc,1)
# (safe;,1)
# (600,000,1)
# (georgia,1)
# (honesty,1)
# (strings,1)
# (star,1)
# (services,1)
# (please,1)
# (cutting-edge,1)
# (oppose,1)
# (effectively,1)
# (beings,1)
# (continuity,1)
# (gridlocked,1)
# (pocket,1)
# (routine,1)
# (attack,1)
# (idea?,1)
# (pastors,1)
# (staff,1)
# (gutting,1)
# (sunday,1)
# (rebates,1)
# (discouraged,1)
# (hanging,1)
# (forty,1)
# (founders,1)
# (wireless,1)
# ($200,1)
# (medicare's,1)
# (edison,1)
# (consume,1)
# (compound;,1)
# (superpower,1)
# (thirty-seven,1)
# (counter-terrorism,1)
# (located,1)
# (informed,1)
# (galesburg,1)
# (occupations,1)
# (connection,1)
# (bureaucratic,1)
# (start:,1)
# (typed,1)
# (assume,1)
# (presents,1)
# (swipe,1)
# (paper-thin,1)
# (collective,1)
# (regenerate,1
# )
# (illness,1)
# (macs,1)
# (drink,1)
# (question:,1)
# ("fix-it-first",1)
# (resale,1)
# (medicine,1)
# (light,1)
# (embarrassing,1)
# (shedding,1)
# (imports,1)
# (newborns,1)
# (drain,1)
# (obstruction,1)
# (london,1)
# (authors,1)
# (deaths;,1)
# (bailing,1)
# (outsourcing,1)
# (represent:,1)
# (railways,1)
# (latino;,1)
# (share?,1)
# (individuals,1)
# (skepticism,1)
# (rangers,1)
# (lifts,1)
# (ibm,1)
# (rises,1)
# (subsidize,1)
# (breakthrough,1)
# (avenue,1)
# (meals,1)
# (teams,1)
# (57,1)
# (prior,1)
# (according,1)
# (pretending,1)
# (upheaval,1)
# (hills,1)
# (exposed,1)
# (atlantic,1)
# (daughter,1)
# (hadiya's,1)
# (bleeding,1)
# (desire,1)
# (cordray,1)
# (emissions,1)
# (oregon,1)
# (speaking,1)
# (realized,1)
# (mass,1)
# (sooner,1)
# (deserved,1)
# (sputters,1)
# (credibility,1)
# (flaw,1)
# (batteries;,1)
# (fig,1)
# (teen,1)
# (prized,1)
# (re-fighting,1)
# (station,1)
# (homeland,1)
# (imprisoned,1)
# (transatlantic,1)
# (lobby,1)
# (fact:,1)
# (builders.",1)
# (revenue,1)
# (witnessed,1)
# (reformed,1)
# (storm;,1)
# (downtown,1)
# (easiest,1)
# ("mad,1)
# (overdue,1)
# (leg,1)
# (run-down,1)
# (dam,1)
# (admire,1)
# (greeted,1)
# (once-shuttered,1)
# (prevailed,1)
# (denver,1)
# (destroy,1)
# (bray,1)
# (fueling,1)
# (romney's,1)
# (rated,1)
# (ceilings,1)
# (spouses,1)
# (nate,1)
# (disrupted,1)
# (microsoft,1)
# (patent,1)
# (instills,1)
# (depths,1)
# (seoul,1)
# (crime,1)
# (wounds,1)
# (expression,1)
# (forcing,1)
# (bookkeeping,1)
# (culture,1)
# (65%,1)
# (prosperous,1)
# (sacrificing,1)
# (reaffirming,1)
# ("there,1)
# (stores,1)
# (situation,1)
# (nation-building,1)
# (generous,1)
# (factors,1)
# (attached,1)
# (fresh,1)
# (fail.",1)
# (title:,1)
# (coincidence,1)
# (pension,1)
# (weak,1)
# (convince,1)
# (marches,1)
# (raises,1)
# (thick,1)
# (posturing,1)
# (globe:,1)
# (disappointment,1)
# (listening,1)
# (bites,1)
# (globalization,1)
# (afloat,1)
# (virtue,1)
# (tack,1)
# (bulldozed,1)
# (repealing,1)
# (spurred,1)
# (inevitable,1)
# (exchange,1)
# (fight;,1)
# (sikh,1)
# (privilege,1)
# (bears,1)
# (accident,1)
# (secretaries;,1)
# (lags,1)
# (automobile,1)
# (disrupting,1)
# (punish,1)
# (best-selling,1)
# (stops,1)
# (verifiable,1)
# (dramatically,1)
# (increases,1)
# (returns,1)
# (unacceptable,1)
# (few;,1)
# (occasion,1)
# (richard,1)
# (berlin;,1)
# (position,1)
# (hopeless,1)
# (sergeant,1)
# (absence,1)
# (backlog,1)
# (detainee,1)
# (shrink,1)
# (divided,1)
# (installing,1)
# (fair?,1)
# (understood,1)
# (technical,1)
# ("that's,1)
# (transfer,1)
# (majorette,1)
# (types,1)
# ("college,1)
# (alternative,1)
# (lies,1)
# (recovers,1)
# (burmese,1)
# (proctor,1)
# (prosecutors,1)
# (pirated,1)
# (supercomputers,1)
# (investigations,1)
# (risk-taker,1)
# (shingles,1)
# (frustrated;,1)
# (facility,1)
# (importantly,1)
# (yardsticks,1)
# (manage,1)
# (reserves,1)
# (enemies;,1)
# (breaks?,1)
# (philippines,1)
# (studies,1)
# (lab,1)
# (education;,1)
# (trouble,1)
# (gravitate,1)
# (color,1)
# (severely,1)
# (refighting,1)
# (banker,1)
# (1200,1)
# (flexibility:,1)
# (husband,1)
# (veterans?,1)
# (offices,1)
# (acceptance,1)
# (lost;,1)
# (cyber-threats,1)
# (regional,1)
# (legacy,1)
# (chips,1)
# (drones,1)
# (pace,1)
# (windows,1)
# (disrupt,1)
# (movies,1)
# (forty-four,1)
# (ethic,1)
# (blind,1)
# (draws,1)
# (fails,1)
# (permitting,1)
# (nurse,1)
# (walls,1)
# (pettiness,1)
# (p-tech,1)
# (500,1)
# (reclaim,1)
# (caregivers,1)
# (72,1)
# (160,1)
# (supplies,1)
# (needless,1)
# (peels,1)
# (job:,1)
# (jobs?,1)
# (hiv/aids,1)
# (patents,1)
# (ago:,1)
# (underway,1)
# (buried,1)
# (it.",1)
# (uncomfortable,1)
# (heads,1)
# (year:,1)
# (act;,1)
# (unleashed,1)
# (dough,1)
# (endured,1)
# (fame,1)
# (device;,1)
# (black-and-white,1)
# (devices,1)
# (teenager,1)
# (stamp,1)
# (speak;,1)
# (graveyard,1)
# (unwilling,1)
# (offers,1)
# (involved,1)
# (chambers,1)
# (verizon,1)
# (victor,1)
# (promoting,1)
# (revamp,1)
# (request,1)
# (adults,1)
# (responding,1)
# (commonsense,1)
# (volunteered,1)
# (broader,1)
# (message:,1)
# ("but,1)
# (kyi,1)
# (2,000-foot,1)
# (devastate,1)
# (frankly,1)
# (saluting,1)
# (truck,1)
# (deployment,1)
# (deceptive,1)
# (covering,1)
# (necessities,1)
# (wrapped,1)
# (cheapest,1)
# (lights,1)
# (declares,1)
# (laboratories,1)
# (visiting,1)
# (drama,1)
# (relocate,1)
# (bridges;,1)
# (wash,1)
# (hesitations,1)
# (eighteen,1)
# (satellite,1)
# (700,1)
# (edge,1)
# (impressive,1)
# (moment;,1)
# (automatically,1)
# (cards,1)
# (upgrading,1)
# (administrations,1)
# (work-study,1)
# (opportunity.",1)
# (grandchildren,1)
# (murphy,1)
# (unionized,1)
# (favors,1)
# (secrets,1)
# (guard,1)
# (digging,1)
# (insists,1)
# (chants,1)
# (3d,1)
# (discover,1)
# (savings:,1)
# (regard,1)
# (movement,1)
# (illinois,1)
# (ty'sheoma,1)
# (destruction;,1)
# (lists,1)
# (swift,1)
# (bone-tired,1)
# (faulty,1)
# (perfect,1)
# (perseveres;,1)
# (sana'a,1)
# (settled,1)
# (leonard,1)
# (tornado,1)
# (gallon,1)
# (tears,1)
# (joked,1)
# (allegiance,1)
# (autoworker,1)
# (stabilize,1)
# (burn,1)
# (surveillance,1)
# (china's,1)
# (prosecuting,1)
# (waver,1)
# (tools,1)
# (sustaining,1)
# (stirs,1)
# (mercury,1)
# (no-bid,1)
# (crucial,1)
# (steadfast,1)
# (bloody,1)
# (three-,1)
# (cynicism,1)
# (160,000,1)
# (library,1)
# (delaying,1)
# (barkeeper,1)
# (conversation,1)
# (revitalize,1)
# (outsourced,1)
# ("nation,1)
# (plentiful,1)
# (touch,1)
# (centrifuges,1)
# ($2.5,1)
# (out-innovate,1)
# (rapidly-changing,1)
# (compare,1)
# (altogether,1)
# (base,1)
# (goods;,1)
# (phoenix,1)
# (stadium,1)
# (war-era,1)
# (scientific,1)
# (howard,1)
# (libya,1)
# (wisconsin,1)
# (defined,1)
# (nation:,1)
# (document,1)
# (tactics,1)
# (pre-requisite,1)
# (shadows,1)
# (philadelphia,1)
# (turning,1)
# (booming,1)
# (spectrum,1)
# (flip,1)
# (buck,1)
# (advances,1)
# (confirmation,1)
# (rightly,1)
# (rio;,1)
# (prosecution,1)
# (quitters,1)
# (manner,1)
# (excel,1)
# (talked,1)
# (skyrocket,1)
# (300,000,1)
# (handles,1)
# (wife,1)
# (cape,1)
# (90,1)
# (restart,1)
# (infuriated,1)
# (miller,1)
# (magazines,1)
# (explosion,1)
# (handing,1)
# (sisters,1)
# (chinese,1)
# (share:,1)
# (governing,1)
# (laundry,1)
# (kansas,1)
# (fairly,1)
# (posts,1)
# (divisive,1)
# (arsenals,1)
# (inaction,1)
# (not:,1)
# (spark,1)
# (embrace,1)
# (well-qualified,1)
# (tuition;,1)
# (september,1)
# (speeding,1)
# (adversity,1)
# (protection,1)
# (campaigned,1)
# (applications,1)
# (engaged,1)
# (germany's,1)
# (societycare,1)
# (rapidly,1)
# (scares,1)
# (beaten,1)
# (release,1)
# (ridge,1)
# (extremist,1)
# (industrialized,1)
# (inexcusable,1)
# (sticker,1)
# (liked,1)
# (determine,1)
# (shaking,1)
# (tripoli,1)
# (hard-hit,1)
# (servicemen,1)
# (resent,1)
# (coastal,1)
# (music,1)
# (devising,1)
# (establish,1)
# (costco,1)
# (mills,1)
# (majorities,1)
# (wealthier,1)
# (midwest,1)
# (per,1)
# (tightening,1)
# (rot,1)
# (democracies,1)
# (bonus,1)
# (inherit,1)
# (treatments,1)
# (underwater,1)
# (amendment,1)
# (colleague,1)
# (bold,1)
# (impoverished,1)
# (wisely,1)
# (incentive,1)
# (wiped,1)
# (founded,1)
# (mobility,1)
# (hardest,1)
# (2012,1)
# (railroads,1)
# (america!",1)
# (tight-knit,1)
# (upside-down,1)
# (begrudge,1)
# (wartime,1)
# (transcontinental,1)
# (benefit,1)
# (uranium,1)
# (d-day,1)
# (warriors,1)
# (ordeal,1)
# (lincoln,1)
# (corps,1)
# (future.",1)
# (sudden,1)
# (boehner,1)
# (pell,1)
# (disabilities;,1)
# (wanted,1)
# (new-found,1)
# (state-of-the,1)
# (floors,1)
# (obtaining,1)
# (functions,1)
# (cheering,1)
# ($10,1)
# (cited,1)
# (boosting,1)
# (native,1)
# (posterity,1)
# (terrible,",1)
# (escalating,1)
# (maintaining,1)
# (foes,1)
# (headlines,1)
# (louisiana,1)
# (faring,1)
# (africa;,1)
# (conrad,1)
# ($2,500,1)
# (range,1)
# (campuses,1)
# (rigid,1)
# (hurricane,1)
# (rushed,1)
# (shouting,1)
# (pandemic,1)
# (e-mail,1)
# (recovered,1)
# (prevented,1)
# (historically,1)
# (former,1)
# (commit,1)
# (anyway,1)
# (fiercely,1)
# (waned,1)
# (would've,1)
# (neighbor;,1)
# (relations,1)
# (inherent,1)
# (usa,1)
# (way.",1)
# (achievement.",1)
# (reignite,1)
# (marchers,1)
# (recent,1)
# (scholarships,1)
# (overlapping,1)
# (draft,1)
# (readying,1)
# (relied,1)
# (betraying,1)
# (builds,1)
# (emerge,1)
# (plainly,1)
# (forty-something,1)
# (seal,1)
# (explaining,1)
# ("made,1)
# (skies,1)
# (traffic,1)
# (dependent,1)
# (restrictions,1)
# (fanfare,1)
# (dozens,1)
# (comforted,1)
# (osama,1)
# (roll,1)
# (encouraged.",1)
# (admirals,1)
# (enforcing,1)
# (ammunition,1)
# (strikes,1)
# (lawmakers,1)
# (bruce,1)
# (ritterby,1)
# (sight,1)
# (attacked,1)
# (fine-tuned,1)
# (option,1)
# (31st,1)
# (accomplish,1)
# (reminding,1)
# (larding,1)
# (west,1)
# (grandmother,1)
# (received,1)
# (hook,1)
# (retail,1)
# (isolate,1)
# (steve's,1)
# (depression;,1)
# (1.6,1)
# (violent,1)
# (schedule,1)
# (that.",1)
# (printing,1)
# (personally,1)
# (face-to-face,1)
# (aung,1)
# (places;,1)
# (maze,1)
# (encouraged,1)
# (carved,1)
# (farthest-reaching,1)
# (saddle,1)
# (chapter,1)
# (iran;,1)
# (groceries,1)
# (possessed,1)
# (stocks,1)
# (participation,1)
# (foreclosure,1)
# (respected,1)
# (objective,1)
# (clearing,1)
# (chances,1)
# (edward,1)
# (accountability,1)
# (grids,1)
# (homebuyers,1)
# (succeeds,1)
# (tighter,1)
# (on-the-job,1)
# (lieberman,1)
# (world?,1)
# (exploration,1)
# (stalled,1)
# (30,1)
# (re-finances,1)
# (diligently,1)
# (surgeries,1)
# (chute,1)
# (ambitious,1)
# (shine,1)
# (stretch,1)
# (prison,1)
# (sudan,1)
# (enriches,1)
# (worsened,1)
# (excelling,1)
# (future:,1)
# (unfair,1)
# (enjoy,1)
# (household,1)
# (guess,1)
# (december,1)
# (250,000,1)
# (eisenhower,1)
# (possibility,1)
# (wright,1)
# (reemployment,1)
# (treasury,1)
# ($5,000,1)
# (taliban's,1)
# (2009,1)
# (yourselves,1)
# (producing,1)
# (derail,1)
# (guides,1)
# (135,000,1)
# (rubio,1)
# (decades:,1)
# (scraping,1)
# (climb,1)
# (ill,1)
# (contributor,1)
# (testament,1)
# (economy;,1)
# (suffer,1)
# (standard,1)
# (el,1)
# (carefully,1)
# (olympic,1)
# (inventions,1)
# (401ks,1)
# (deterrent,1)
# (passion,1)
# (wear,1)
# (afraid,",1)
# (consign,1)
# (client,1)
# (bar,1)
# (outgunned,1)
# (constitution:,1)
# (reverses,1)
# (departments,1)
# (separated,1)
# (current,1)
# (correctional,1)
# (fear;,1)
# (punishes,1)
# (warned,1)
# (all-time,1)
# (empowering,1)
# (provocations,1)
# (fees,1)
# (cyber-attacks,1)
# (breathe,1)
# (re-financing,1)
# (unclogging,1)
# (efficiencies,1)
# (veteran,1)
# (vigorously,1)
# (guns,1)
# (deeds,1)
# (nature,1)
# (reflect,1)
# (outsized,1)
# (shrapnel,1)
# (import,1)
# (declining,1)
# (front,1)
# (captures,1)
# (michelle's,1)
# (pundits,1)
# (possibilities,1)
# (graduations,1)
# (usa.",1)
# (dropping,1)
# (obsess,1)
# (patients',1)
# (closing,1)
# (revenues,1)
# (tractorsgrocery,1)
# (toxic,1)
# (lifetime,1)
# (organized,1)
# (mired,1)
# (longest-serving,1)
# (reliance,1)
# (parent/teacher,1)
# (guinea,1)
# (polling,1)
# (turf,1)
# (2001,1)
# (pictures,1)
# (conquer,1)
# (forebears,1)
# (mexico,1)
# (down-payment,1)
# (biomedical,1)
# (possessions,1)
# (crisis,",1)
# (industrial,1)
# (caused,1)
# (ukraine,1)
# (wealth,1)
# (fearful,1)
# (farms,1)
# (crises,1)
# (eleven,1)
# (drifting,1)
# (organs;,1)
# (spilled,1)
# (made.",1)
# (firefighter,1)
# (certainty,1)
# (coburn,1)
# (start-ups,1)
# (shores?,1)
# (self-government;,1)
# (larger,1)
# (weighed,1)
# (torn,1)
# (viable,1)
# (art,1)
# (infectious,1)
# (agrees,1)
# (assisting,1)
# (bomber,1)
# (tenth,1)
# (saltwater,1)
# (tests,1)
# (fancy,1)
# ([on],1)
# (highs,1)
# (sheer,1)
# (priced,1)
# (oldest,1)
# (repaid,1)
# (church,1)
# (impossible,1)
# (she'll,1)
# (entitlement,1)
# (retool,1)
# (preference,1)
# (dreaming,1)
# (exception,1)
# (management,1)
# (revolutionize,1)
# (automaker,1)
# ($140,1)
# (ninety-eight,1)
# (malls,1)
# (challenge:,1)
# (flags,1)
# ("nothing,1)
# (occupy,1)
# (recognizes,1)
# (nonpartisan,1)
# (applaud,1)
# (shaken;
# ,1)
# (dwight,1)
# (collaboration,1)
# (abide,1)
# (cents,1)
# (anger,1)
# (cairo;,1)
# (cool,1)
# (speculators,1)
# (hasn't,1)
# (up.",1)
# (cure,1)
# (people:,1)
# (temple,1)
# (targeting,1)
# (naysayers,1)
# (27,1)
# (aspires,1)
# (there;,1)
# (hearts,1)
# (carrying,1)
# (letters,1)
# (playbook,1)
# (pat,1)
# (enriching,1)
# (campus,1)
# (count,1)
# (obvious,1)
# (spikes,1)
# (supplant,1)
# (pioneers,1)
# (revitalized,1)
# (sank,1)
# (electric,1)
# (180,000,1)
# (hybrids,1)
# (mere,1)
# (related,1)
# (performing,1)
# ($3,1)
# (employed,1)
# (pounded,1)
# (convictions,1)
# (celebrated,1)
# (3,1)
# (stifled,1)
# (yield,1)
# (tunis,1)
# (boom,1)
# (apollo,1)
# (supreme,1)
# (lock's,1)
# (disease;,1)
# (piling,1)
# (tuck,1)
# (hackers,1)
# (managed,1)
# (robotics,1)
# (anew,1)
# (enact,1)
# (versa,1)
# (expenses,1)
# (lightening,1)
# (overloaded,1)
# (deficient,1)
# (neighborhoods,1)
# (rolling,1)
# (fisher,1)
# (outsource,1)
# (horse-trading,1)
# (summed,1)
# (likewise,1)
# (panels,1)
# (bacteria,1)
# (anchor,1)
# (sits,1)
# (vehicles,1)
# (soviets,1)
# (missed,1)
# (elkhart,1)
# (flexible,1)
# (land,1)
# (bottom:,1)
# (software,1)
# (urgency,1)
# (afghanistan;,1)
# (2007,1)
# (plot,1)
# (clinton,1)
# (3rd,1)
# (chats,1)
# (eats,1)
# (contemplating,1)
# (silly,1)
# (trusted,1)
# (post-partisan,1)
# (pan,1)
# (damaged,1)
# (attractive,1)
# (creed,1)
# (bond,1)
# (christian,1)
# (most:,1)
# (training;,1)
# (accelerate,1)
# (expire,1)
# (cynical,1)
# (operation,1)
# (399,1)
# (distance,1)
# (sowing,1)
# (universities;,1)
# (destroyed,1)
# (usually,1)
# (speaks,1)
# (battery,1)
# (boomers,1)
# (picking,1)
# (ensuring,1)
# (poll,1)
# (judicial,1)
# (abuses,1)
# (strain,1)
# (trivial,1)
# (resilient,1)
# (rent,1)
# (turnover,1)
# (nearby,1)
# (imposed,1)
# (smoked,1)
# (presidents,1)
# (qualities,1)
# (senseless,1)
# (offender,1)
# (gate,1)
# (charter,1)
# (forget:,1)
# (clinging,1)
# (saddled,1)
# (dairy,1)
# (india's,1)
# (temporary,1)
# (progress.",1)
# (wheel,1)
# (flat,1)
# (drop,1)
# (wondering,1)
# (ample,1)
# (frustrates,1)
# (refinance,1)
# (closest,1)
# (defeating,1)
# (102,1)
# (repairing,1)
# (drill,1)
# (weathered,1)
# (pendleton,1)
# (robust,1)
# (jackie's,1)
# (tires,1)
# (burning,1)
# (billionaires,1)
# (peaceful,1)
# (golden,1)
# (predict,1)
# (yearn,1)
# (uniforms,1)
# (sadly,1)
# (imaginations,1)
# (significant,1)
# (complain,1)
# (deposited,1)
# (adhere,1)
# (entities,1)
# (mouse,1)
# (borrowing,1)
# (equivocation,1)
# (inspector,1)
# (2%,1)
# ($9.00,1)
# (devastated,1)
# (shirk,1)
# (crossroads,1)
# (poor;,1)
# (equations,1)
# (anguish,1)
# (brinksmanship,1)
# (regions,1)
# (improving,1)
# (chemicals,1)
# (profound,1)
# (kindness",1)
# (ranger,1)
# (confronting,1)
# (expressed,1)
# (enlist,1)
# (four-hour,1)
# (year-old,1)
# (clear-eyed,1)
# (10,000,1)
# (quitters.",1)
# (mark,1)
# (self-healing,1)
# (differences;,1)
# (fifty-one,1)
# (highly,1)
# (governmentour,1)
# (fathers,1)
# (neighbors,",1)
# (herself,1)
# (agribusinesses,1)
# (scores,1)
# (gutted,1)
# (fed,1)
# (statistics,1)
# (grudges,1)
# (locating,1)
# (transformed,1)
# (d.c,1)
# (group,1)
# (re-tooled,1)
# (mccain,1)
# (soaring,1)
# (test;,1)
# (packing,1)
# (jet,1)
# (inescapable,1)
# (graded,1)
# (stubborn,1)
# (judd,1)
# (disagreements,1)
# (abandon,1)
# (arms,1)
# (wean,1)
# (cleo,1)
# (boys,1)
# (emergency,1)
# (seconds,1)
# (repay,1)
# (hampering,1)
# (excess,1)
# (arrive,1)
# (districts,1)
# (partnered,1)
# (evolved,1)
# (texas,1)
# (transit,1)
# (performance;,1)
# (period,1)
# (roosevelt,1)
# (population,1)
# (stars,1)
# (horizon,1)
# (diversity,1)
# (belt,1)
# (errors,1)
# (packaging,1)
# (extract,1)
# (super,1)
# (real-world,1)
# (establishing,1)
# (things.",1)
# (seeks,1)
# (insourcing,1)
# (flooded,1)
# (proliferation;,1)
# (below,1)
# (sound,1)
# (pipelines,1)
# (slipped,1)
# (supposed,1)
# (sleep,1)
# (taunts,1)
# (laboratory,1)
# (from;,1)
# (friend;,1)
# (league,1)
# (forbidden,1)
# (nominations,1)
# (tampa,1)
# (conferences,1)
# (rancor,1)
# (generosity,1)
# (efforts:,1)
# ("it,1)
# (barrels,1)
# (textbook;,1)
# (strict,1)
# (oversight,1)
# (lip,1)
# (violating,1)
# (allies;,1)
# (orlando,1)
# (pregnancy,1)
# (inspires,1)
# (patrols,1)
# (consensus,1)
# (stolen,1)
# (insurgency,1)
# (strife,1)
# (wastes,1)
# (stark,1)
# (drapes,1)
# (conflicts,1)
# (spouse,1)
# (describe,1)
# (500,000,1)
# (50-year,1)
# (moreover,1)
# (narrow,1)
# (laser,1)
# (grade,1)
# (frivolous,1)
# (vests,1)
# (freely,1)
# (obtain,1)
# (stale,1)
# (bethea,1)
# (iron-clad,1)
# ("if,1)
# (worry,1)
# (rocketed,1)
# (solved,1)
# (attempt,1)
# (stranglehold,1)
# (typhoon,1)
# (bank;,1)
# (34,000,1)
# (hunger,1)
# (nasa,1)
# (presume,1)
# (mine,1)
# (lack,1)
# (leak,1)
# (responders,1)
# (civilian,1)
# (speculation,1)
# (high-paying,1)
# (helicopter,1)
# (genome,1)
# ($30,1)
# (apprenticeship,1)
# (model,1)
# (warehouse,1)
# (abusive,1)
# (sequester,",1)
# (signing,1)
# (child;,1)
# (harkin,1)
# (admit,1)
# (safeguards,1)
# (hardest-working,1)
# ("expansion",1)
# (lit,1)
# (mile,1)
# (retired,1)
# (toughest,1)
# (toledo,1)
# (danced,1)
# (alabama,1)
# (formative,1)
# (keen,1)
# (recedes,1)
# (hoover,1)
# (secretary;,1)
# (intentions,1)
# (name,1)
# (task,",1)
# (all.",1)
# (leaner,1)
# (weaker,1)
# (recovery.gov,1)
# (hottest,1)
# (commutes,1)
# (rodriguez,1)
# (secured,1)
# (unlikely,1)
# (company.",1)
# (surpass,1)
# (matches,1)
# (system's,1)
# (dwindle,1)
# (freak,1)
# (indispensable,1)
# (couples,1)
# (practical,1)
# (bull,1)
# (ready-to-work,1)
# (thirteen,1)
# (classified,1)
# (factories;,1)
# (calls,1)
# (florida,1)
# (shown,1)
# (how?,1)
# (whom,1)
# (choice:,1)
# (residents,1)
# (opponent,1)
# (visitors,1)
# (aspiring,1)
# (gary,1)
# (sends,1)
# (awful,1)
# (strongholds,1)
# (tuesday,1)
# (dates,1)
# (conclusion,1)
# (house;,1)
# (trust;,1)
# (automatic,1)
# (chief,1)
# (purchase,1)
# (falling,1)
# (consequential,1)
# (dictators,1)
# (dries,1)
# (reset,1)
# (erupted,1)
# (stability,1)
# (verify,1)
# (proves,1)
# (catalyzed,1)
# (anywhere,1)
# (predecessor,1)
# (watchdog,1)
# (collected,1)
# (though:,1)
# ("living,1)
# (rob,1)
# (hostage,1)
# (roadside,1)
# (keeping,1)
# (manufactured,1)
# (excessive,1)
# (hillary,1)
# (obsolete,1)
# (fuels,1)
# (durable,1)
# (ravages,1)
# (2005,1)
# (stood,1)
# (out-build,1)
# (latino,1)
# (waterways,1)
# (warren,1)
# (celebrity,1)
# (wins,1)
# (contracts,1)
# (compared,1)
# (replaces,1)
# (candor,1)
# (candidate,1)
# (colorado,1)
# (thread;,1)
# (envoy,1)
# (homelessness,1)
# (better-positioned,1)
# (caterpillar,1)
# (nights,1)
# (ninth,1)
# (piles,1)
# (seeker,1)
# (excuse,1)
# (independents,1)
# (particular,1)
# (anti-fraud,1)
# (games,1)
# (battered,1)
# (divide,1)
# (ambition,1)
# (mistrust,1)
# (intimidation,1)
# (malpractice,1)
# (stumble;,1)
# (cede,1)
# (predicting,1)
# (years;,1)
# (stretches,1)
# (dropout,1)
# (parade,1)
# (court,1)
# (balances,1)
# (deteriorating,1)
# (kills,1)
# (newer,1)
# (enrich,1)
# (suu,1)
# (out;,1)
# (exploiting,1)
# (gratitude,1)
# (retirees,1)
# (finest,1)
# ("to,1)
# (rivals,1)
# (pick,1)
# (criteria:,1)
# (honors,1)
# (7,1)
# (startup,1)
# (legislative,1)
# (high-powered,1)
# (storefronts,1)
# (stations,1)
# (jews,1)
# (bob,1)
# (cash-strapped,1)
# (publish,1)
# (try.",1)
# (dialed,1)
# (enrolled,1)
# (copouts,1)
# (august,1)
# (prospects,1)
# (multinational,1)
# (election-year,1)
# (extension,1)
# (hezbollah,1)
# (minutes,1)
# (liberty,1)
# (65th,1)
# (temperatures,1)
# (number:,1)
# (episode,1)
# (consequence,1)
# (reach:,1)
# (angry,1)
# (hike,1)
# (employer,1)
# (pathways,1)

# %%
val wordCountGWBClean = wordCountGWB.filter(t => !commonWords.contains(t._1))
wordCountGWBClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,702)
# (america,207)
# (people,158)
# (must,153)
# (world,131)
# (country,108)
# (american,104)
# (congress,99)
# (americans,99)
# (security,98)
# (help,90)
# (nation,88)
# (terrorists,83)
# (iraq,80)
# (freedom,79)

# %%
val wordCountWJCClean = wordCountWJC.filter(t => !commonWords.contains(t._1))
wordCountWJCClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,1046)
# (must,289)
# (people,266)
# (work,194)
# (america,188)
# (years,176)
# (children,153)
# (americans,152)
# (congress,147)
# (american,136)
# (help,117)
# (care,116)
# (world,108)
# (health,102)
# (tonight,98)

# %%
val wordCountJFKClean = wordCountJFK.filter(t => !commonWords.contains(t._1))
wordCountJFKClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,299)
# (world,63)
# (must,51)
# (free,46)
# (nations,46)
# (other,45)
# (own,42)
# (congress,35)
# (national,35)
# (economic,34)
# (any,33)
# (defense,33)
# (only,33)
# (nation,31)
# (tax,31)

# %%
val wordCountFDRClean = wordCountFDR.filter(t => !commonWords.contains(t._1))
wordCountFDRClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,980)
# (war,238)
# (world,167)
# (must,161)
# (government,154)
# (people,141)
# (national,130)
# (other,124)
# (nation,122)
# (peace,111)
# (nations,111)
# (united,106)
# (congress,105)
# (american,97)
# (many,94)

# %%
val wordCountALClean = wordCountAL.filter(t => !commonWords.contains(t._1))
wordCountALClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,316)
# (states,148)
# (upon,84)
# (united,81)
# (any,79)
# (congress,77)
# (government,73)
# (people,70)
# (other,69)
# (war,64)
# (country,62)
# (great,61)
# (shall,53)
# (union,53)
# (time,51)

# %%
val wordCountGWClean = wordCountGW.filter(t => !commonWords.contains(t._1))
wordCountGWClean.sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (,241)
# (states,91)
# (united,86)
# (public,54)
# (government,47)
# (your,47)
# (made,39)
# (upon,38)
# (my,37)
# (other,37)
# (citizens,33)
# (state,32)
# (country,31)
# (peace,30)
# (shall,30)

# %%
wordCountFDRClean.subtractByKey(wordCountBOClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (present,39)
# (japanese,36)
# (essential,31)
# (therefore,31)
# (enemy,24)
# (1942,22)
# (methods,21)
# (adequate,21)
# (peoples,20)
# (principles,20)
# (objectives,19)
# (however,19)
# (1933,19)
# (agriculture,18)
# (civilization,18)

# %%
wordCountBOClean.subtractByKey(wordCountFDRClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (energy,87)
# (tonight,84)
# (businesses,69)
# (college,40)
# (schools,36)
# (students,27)
# (oil,26)
# (republicans,25)
# (kids,25)
# (innovation,24)
# (democrats,23)
# (gas,23)
# (research,22)
# (nuclear,21)
# (technology,20)

# %%
wordCountBOClean.subtractByKey(wordCountGWBClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (banks,22)
# (industry,20)
# (trillion,17)
# (middle-class,13)
# (wage,12)
# (class,12)
# (lay,11)
# (lending,11)
# (walk,11)
# (forge,11)
# (helps,10)
# (restore,10)
# (minimum,10)
# (partnership,9)
# (breaks,9)

# %%
wordCountBOClean.subtractByKey(wordCountGWClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (jobs,148)
# (america,131)
# (americans,105)
# (tonight,84)
# (help,81)
# (businesses,69)
# (health,55)
# (back,53)
# (job,51)
# (reform,51)
# (deficit,48)
# (down,47)
# (today,40)
# (college,40)
# (can't,39)

# %%
wordCountBOClean.subtractByKey(wordCountALClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (jobs,148)
# (tonight,84)
# (businesses,69)
# (families,56)
# (job,51)
# (deficit,48)
# (today,40)
# (college,40)
# (can't,39)
# (million,36)
# (schools,36)
# (workers,35)
# (clean,35)
# (hard,32)
# (budget,30)

# %%
wordCountWJCClean.subtractByKey(wordCountALClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (tonight,98)
# (families,82)
# (budget,77)
# (challenge,76)
# (parents,70)
# (jobs,66)
# (schools,66)
# (child,65)
# (million,64)
# (crime,60)
# (today,60)
# (21st,58)
# (college,54)
# (thank,47)
# (bill,47)

# %%
wordCountGWBClean.subtractByKey(wordCountALClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (terrorists,83)
# (iraq,80)
# (tonight,76)
# (terror,63)
# (weapons,56)
# (iraqi,48)
# (jobs,36)
# (terrorist,36)
# (workers,36)
# (al,36)
# (afghanistan,35)
# (nuclear,32)
# (qaeda,32)
# (goal,32)
# (million,31)

# %%
wordCountALClean.subtractByKey(wordCountBOClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (persons,30)
# (naval,27)
# (present,27)
# (emancipation,25)
# (consideration,22)
# (receipts,22)
# (however,21)
# (measures,20)
# (slavery,19)
# (indian,17)
# (vessels,17)
# (proclamation,17)
# (powers,16)
# (rebellion,16)
# (actual,16)

# %%
wordCountALClean.subtractByKey(wordCountWJCClean).sortBy(_._2, ascending = false).take(15).foreach(println)
# Out:
# (persons,30)
# (navy,28)
# (condition,28)
# (naval,27)
# (emancipation,25)
# (thus,23)
# (consideration,22)
# (receipts,22)
# (claims,20)
# (interior,18)
# (vessels,17)
# (proclamation,17)
# (powers,16)
# (rebellion,16)
# (revenue,16)
